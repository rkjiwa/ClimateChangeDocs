# %% [markdown]
# # PDFs to Text via PyPDF2

# %% [markdown]
# This file is to convert pdf files into text files by using PyPDF2. It has been designed to search the current directory, and return a folder containing the converted text files.
#
# This code was initially written for the UofT3666 - Applied Natural Language Processing final project.

# %%
#imports
import PyPDF2
import os
import glob

# %%
# this class is to extract the text using pypdf2
class PyPDF2Extract(object):
    # initialize the class
    def __init__(self, target_directory_name):
        self.target = str(target_directory_name)
        
        
    # define a function to extract a pdf 
    def pdfExtract(self, file):
        # open the pdf file
        pdf = open(file, 'rb')
        # convert the pdf to a PdfFileReader object
        read_pdf = PyPDF2.PdfFileReader(pdf)
        # check if the pdf file is encrypted
        if read_pdf.isEncrypted == True:
            print(file + ' file is encrypted')
        else:
            print(file)
            # get the page content
            page_content = []
            # get the number of pages in the document
            number_of_pages = read_pdf.getNumPages()
            # iterate over each page to extract the text
            for i in range(number_of_pages):
                page = read_pdf.getPage(i)
                # some of the files throws a TypeError
                # others may throw a KeyError if there is a blank page
                # this has not been addressed here
                try:
                    content = page.extractText()
                    page_content.append(content)
                except TypeError:
                    pass
                # set condition for writing the text file
                if (i+ 1) == number_of_pages:
                    # write the text file
                    with open(str(os.getcwd()) + '/' + self.target + '/' + file[:-4] + '.txt', 'w') as f:
                        f.write(str(page_content) + "\n")
                        print(file + ' success')
    
    def transform(self):
        # resolve files in directory using glob
        files = list(glob.glob("*.pdf"))
        # iterate over files to run pdfExtract function
        for i in files:
            #check if the target directory exists, if it doesn't create the target
            if not os.path.exists(str(os.getcwd()) + '/' + self.target):
                os.makedirs(str(os.getcwd()) + '/' + self.target)
            self.pdfExtract(i)

# %%
# initialization the PyPDF2Extract class, specifying the target directory name
pypdf2_extractor = PyPDF2Extract(target_directory_name = 'pypdf2_extracted_texts')

# %%
#perform the transformation
pypdf2_extractor.transform()
# Out:
# Climate Change Adaptation - A Priorities Plan for Canada (2012).pdf
# Climate Change Adaptation - A Priorities Plan for Canada (2012).pdf success
# waterloo_region_climate_projections_final_revised30oct2015.pdf
# waterloo_region_climate_projections_final_revised30oct2015.pdf success
# the_london_plan_malp_march_2016_-_chapter_5_-_londons_response_to_climate_change.pdf
# the_london_plan_malp_march_2016_-_chapter_5_-_londons_response_to_climate_change.pdf success
# nc6_can_resubmission_english.pdf file is encrypted
# nld.pdf
# nld.pdf success
# Energy+agenda.pdf
# Energy+agenda.pdf success
# Tr045.pdf
# Tr045.pdf success
# pac_third_report_2019_02_27.pdf
# pac_third_report_2019_02_27.pdf success
# env-yukon-state-play-analysis-climate-change-impacts-adaptation.pdf
# env-yukon-state-play-analysis-climate-change-impacts-adaptation.pdf success
# IPCC_SRREN_Ch01.pdf
# IPCC_SRREN_Ch01.pdf success
# UK-CCRA-2017-Synthesis-Report-Committee-on-Climate-Change.pdf
# UK-CCRA-2017-Synthesis-Report-Committee-on-Climate-Change.pdf success
# 20170125-en.pdf
# 20170125-en.pdf success
# PB_Are_the_Dutch_going_green.pdf
# PB_Are_the_Dutch_going_green.pdf success
# BC-Agriculture-Climate-Change-Action-Plan.pdf
# BC-Agriculture-Climate-Change-Action-Plan.pdf success
# Perspectives on Climate Change Action in Canada English.pdf
# Perspectives on Climate Change Action in Canada English.pdf success
# info_sheets_summaires.pdf
# info_sheets_summaires.pdf success
# CAT_research_plan_2015.pdf
# CAT_research_plan_2015.pdf success
# Environment-and-Renewable-Energy-Workshop-Presentation-Abstracts-final.pdf
# Environment-and-Renewable-Energy-Workshop-Presentation-Abstracts-final.pdf success
# climatechangeindicators-13sept2016_final.pdf
# climatechangeindicators-13sept2016_final.pdf success
# AtlanticRegionAdaptationScienceActivitiesReport.pdf
# AtlanticRegionAdaptationScienceActivitiesReport.pdf success
# Indicator_Report_Final_web.pdf
# Indicator_Report_Final_web.pdf success
# ff-climate.pdf
# ff-climate.pdf success
# ClimatecommunicationsintheNetherlands.pdf
# ClimatecommunicationsintheNetherlands.pdf success
# Climate Change and Energy Sector.pdf file is encrypted
# CoucilReport_july4_EN_Web.pdf
# CoucilReport_july4_EN_Web.pdf success
# climate-change-ca.pdf
# climate-change-ca.pdf success
# London_tech.pdf
# London_tech.pdf success
# A_Canadian_Opportunity_-_Tackling_climate_change_by_switching_to_clean_power.pdf
# A_Canadian_Opportunity_-_Tackling_climate_change_by_switching_to_clean_power.pdf success
# 2017BernardSoubryPolicyBrief.pdf
# 2017BernardSoubryPolicyBrief.pdf success
# WP_Health_November2008.pdf
# WP_Health_November2008.pdf success
# climate-change-health-impacts-california-ib.pdf
# climate-change-health-impacts-california-ib.pdf success
# CCCR_FULLREPORT-EN-FINAL.pdf
# CCCR_FULLREPORT-EN-FINAL.pdf success
# Adapting_to_a_Changing_Climate_in_NS.pdf
# Adapting_to_a_Changing_Climate_in_NS.pdf success

# %%
# operationalize
if __name__ == "__main__":
    pypdf2_extractor = PyPDF2Extract(target_directory_name = 'pypdf2_extracted_texts')
    pypdf2_extractor.transform()
# Out:
# Climate Change Adaptation - A Priorities Plan for Canada (2012).pdf
# Climate Change Adaptation - A Priorities Plan for Canada (2012).pdf success
# waterloo_region_climate_projections_final_revised30oct2015.pdf
# waterloo_region_climate_projections_final_revised30oct2015.pdf success
# the_london_plan_malp_march_2016_-_chapter_5_-_londons_response_to_climate_change.pdf
# the_london_plan_malp_march_2016_-_chapter_5_-_londons_response_to_climate_change.pdf success
# nc6_can_resubmission_english.pdf file is encrypted
# nld.pdf
# nld.pdf success
# Energy+agenda.pdf
# Energy+agenda.pdf success
# Tr045.pdf
# Tr045.pdf success
# pac_third_report_2019_02_27.pdf
# pac_third_report_2019_02_27.pdf success
# env-yukon-state-play-analysis-climate-change-impacts-adaptation.pdf
# env-yukon-state-play-analysis-climate-change-impacts-adaptation.pdf success
# IPCC_SRREN_Ch01.pdf
# IPCC_SRREN_Ch01.pdf success
# UK-CCRA-2017-Synthesis-Report-Committee-on-Climate-Change.pdf
# UK-CCRA-2017-Synthesis-Report-Committee-on-Climate-Change.pdf success
# 20170125-en.pdf
# 20170125-en.pdf success
# PB_Are_the_Dutch_going_green.pdf
# PB_Are_the_Dutch_going_green.pdf success
# BC-Agriculture-Climate-Change-Action-Plan.pdf
# BC-Agriculture-Climate-Change-Action-Plan.pdf success
# Perspectives on Climate Change Action in Canada English.pdf
# Perspectives on Climate Change Action in Canada English.pdf success
# info_sheets_summaires.pdf
# info_sheets_summaires.pdf success
# CAT_research_plan_2015.pdf
# CAT_research_plan_2015.pdf success
# Environment-and-Renewable-Energy-Workshop-Presentation-Abstracts-final.pdf
# Environment-and-Renewable-Energy-Workshop-Presentation-Abstracts-final.pdf success
# climatechangeindicators-13sept2016_final.pdf
# climatechangeindicators-13sept2016_final.pdf success
# AtlanticRegionAdaptationScienceActivitiesReport.pdf
# AtlanticRegionAdaptationScienceActivitiesReport.pdf success
# Indicator_Report_Final_web.pdf
# Indicator_Report_Final_web.pdf success
# ff-climate.pdf
# ff-climate.pdf success
# ClimatecommunicationsintheNetherlands.pdf
# ClimatecommunicationsintheNetherlands.pdf success
# Climate Change and Energy Sector.pdf file is encrypted
# CoucilReport_july4_EN_Web.pdf
# CoucilReport_july4_EN_Web.pdf success
# climate-change-ca.pdf
# climate-change-ca.pdf success
# London_tech.pdf
# London_tech.pdf success
# A_Canadian_Opportunity_-_Tackling_climate_change_by_switching_to_clean_power.pdf
# A_Canadian_Opportunity_-_Tackling_climate_change_by_switching_to_clean_power.pdf success
# 2017BernardSoubryPolicyBrief.pdf
# 2017BernardSoubryPolicyBrief.pdf success
# WP_Health_November2008.pdf
# WP_Health_November2008.pdf success
# climate-change-health-impacts-california-ib.pdf
# climate-change-health-impacts-california-ib.pdf success
# CCCR_FULLREPORT-EN-FINAL.pdf
# CCCR_FULLREPORT-EN-FINAL.pdf success
# Adapting_to_a_Changing_Climate_in_NS.pdf
# Adapting_to_a_Changing_Climate_in_NS.pdf success
