# %% [markdown]
# # LDA using Gensim

# %% [markdown]
# This notebook, goes through performing LDA on the text documents of the Climate Change PDFs using Gensim.
#
# In this notebook, we will:
# - identify the files and come up with a file list
# - load the stopwords
# - functionally get the documents
# - normalize the documents
# - create the dictionary and corpus
# - create id2word
# - initialize and train the model
# - print out top topics
# - determine the coherence score and perplexity
# - create and save a visualization of topics using pyLDAvis
# - test how an external document fits into the model

# %%
#imports
import codecs
import pandas as pd
import numpy as np
import os
import json
import time
import csv
import sklearn
import nltk
nltk.download('all')
import unicodedata
from nltk.corpus import PlaintextCorpusReader
from nltk.tokenize import WordPunctTokenizer
from nltk import pos_tag, sent_tokenize, wordpunct_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import CountVectorizer
from gensim.corpora import Dictionary
from sklearn.base import BaseEstimator, TransformerMixin
from pprint import pprint
from gensim.corpora import Dictionary
from gensim.models import LdaModel
from gensim.models.callbacks import PerplexityMetric
from gensim.models.callbacks import CoherenceMetric
from gensim.models.coherencemodel import CoherenceModel
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
import pyLDAvis.gensim
import pyLDAvis
from gensim.models import TfidfModel
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package cess_esp is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package city_database to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package city_database is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package comparative_sentences is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package comtrans to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package comtrans is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package conll2002 is already up-to-date!
# [nltk_data]    | Downloading package conll2007 to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package conll2007 is already up-to-date!
# [nltk_data]    | Downloading package crubadan to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package crubadan is already up-to-date!
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package dependency_treebank is already up-to-date!
# [nltk_data]    | Downloading package dolch to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package dolch is already up-to-date!
# [nltk_data]    | Downloading package europarl_raw to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package europarl_raw is already up-to-date!
# [nltk_data]    | Downloading package floresta to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package floresta is already up-to-date!
# [nltk_data]    | Downloading package framenet_v15 to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package framenet_v15 is already up-to-date!
# [nltk_data]    | Downloading package framenet_v17 to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package framenet_v17 is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package ieer to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package ieer is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package indian to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package indian is already up-to-date!
# [nltk_data]    | Downloading package jeita to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package jeita is already up-to-date!
# [nltk_data]    | Downloading package kimmo to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package kimmo is already up-to-date!
# [nltk_data]    | Downloading package knbc to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package knbc is already up-to-date!
# [nltk_data]    | Downloading package lin_thesaurus to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package lin_thesaurus is already up-to-date!
# [nltk_data]    | Downloading package mac_morpho to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package mac_morpho is already up-to-date!
# [nltk_data]    | Downloading package machado to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package machado is already up-to-date!
# [nltk_data]    | Downloading package masc_tagged to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package masc_tagged is already up-to-date!
# [nltk_data]    | Downloading package moses_sample to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package moses_sample is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package nombank.1.0 to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package nombank.1.0 is already up-to-date!
# [nltk_data]    | Downloading package nps_chat to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package nps_chat is already up-to-date!
# [nltk_data]    | Downloading package omw to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package opinion_lexicon to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package opinion_lexicon is already up-to-date!
# [nltk_data]    | Downloading package paradigms to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package paradigms is already up-to-date!
# [nltk_data]    | Downloading package pil to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package pil is already up-to-date!
# [nltk_data]    | Downloading package pl196x to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package pl196x is already up-to-date!
# [nltk_data]    | Downloading package ppattach to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package ppattach is already up-to-date!
# [nltk_data]    | Downloading package problem_reports to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package problem_reports is already up-to-date!
# [nltk_data]    | Downloading package propbank to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package propbank is already up-to-date!
# [nltk_data]    | Downloading package ptb to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package ptb is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_1 to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package product_reviews_1 is already up-to-date!
# [nltk_data]    | Downloading package product_reviews_2 to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package product_reviews_2 is already up-to-date!
# [nltk_data]    | Downloading package pros_cons to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package pros_cons is already up-to-date!
# [nltk_data]    | Downloading package qc to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package qc is already up-to-date!
# [nltk_data]    | Downloading package reuters to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package reuters is already up-to-date!
# [nltk_data]    | Downloading package rte to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package rte is already up-to-date!
# [nltk_data]    | Downloading package semcor to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package semcor is already up-to-date!
# [nltk_data]    | Downloading package senseval to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package senseval is already up-to-date!
# [nltk_data]    | Downloading package sentiwordnet to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package sentiwordnet is already up-to-date!
# [nltk_data]    | Downloading package sentence_polarity to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package sentence_polarity is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package sinica_treebank to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package sinica_treebank is already up-to-date!
# [nltk_data]    | Downloading package smultron to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package smultron is already up-to-date!
# [nltk_data]    | Downloading package state_union to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package state_union is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package subjectivity to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package subjectivity is already up-to-date!
# [nltk_data]    | Downloading package swadesh to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package swadesh is already up-to-date!
# [nltk_data]    | Downloading package switchboard to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package switchboard is already up-to-date!
# [nltk_data]    | Downloading package timit to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package timit is already up-to-date!
# [nltk_data]    | Downloading package toolbox to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package toolbox is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package udhr to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package udhr is already up-to-date!
# [nltk_data]    | Downloading package udhr2 to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package udhr2 is already up-to-date!
# [nltk_data]    | Downloading package unicode_samples to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package unicode_samples is already up-to-date!
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package universal_treebanks_v20 is already up-to-
# [nltk_data]    |       date!
# [nltk_data]    | Downloading package verbnet to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package verbnet is already up-to-date!
# [nltk_data]    | Downloading package verbnet3 to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package verbnet3 is already up-to-date!
# [nltk_data]    | Downloading package webtext to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package webtext is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package ycoe to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package ycoe is already up-to-date!
# [nltk_data]    | Downloading package rslp to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package rslp is already up-to-date!
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package maxent_treebank_pos_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package universal_tagset to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package universal_tagset is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package book_grammars to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package book_grammars is already up-to-date!
# [nltk_data]    | Downloading package sample_grammars to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package sample_grammars is already up-to-date!
# [nltk_data]    | Downloading package spanish_grammars to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package spanish_grammars is already up-to-date!
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package basque_grammars is already up-to-date!
# [nltk_data]    | Downloading package large_grammars to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package large_grammars is already up-to-date!
# [nltk_data]    | Downloading package tagsets to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package tagsets is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package bllip_wsj_no_aux to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package bllip_wsj_no_aux is already up-to-date!
# [nltk_data]    | Downloading package word2vec_sample to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package word2vec_sample is already up-to-date!
# [nltk_data]    | Downloading package panlex_swadesh to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package panlex_swadesh is already up-to-date!
# [nltk_data]    | Downloading package mte_teip5 to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package mte_teip5 is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package perluniprops to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package perluniprops is already up-to-date!
# [nltk_data]    | Downloading package nonbreaking_prefixes to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package nonbreaking_prefixes is already up-to-date!
# [nltk_data]    | Downloading package vader_lexicon to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package vader_lexicon is already up-to-date!
# [nltk_data]    | Downloading package porter_test to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package porter_test is already up-to-date!
# [nltk_data]    | Downloading package wmt15_eval to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package wmt15_eval is already up-to-date!
# [nltk_data]    | Downloading package mwa_ppdb to
# [nltk_data]    |     /Users/rahimjiwa/nltk_data...
# [nltk_data]    |   Package mwa_ppdb is already up-to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection all

# %%
# let's start by running over the folder where our files are, we can use the plaintextcorpusreader to obtain the fileids
reader = PlaintextCorpusReader('tikatextcombined','.*txt')
# trying with added new docs

# %%
# create a list of fileids
file_list = reader.fileids()
file_list
# Out:
# ['20170125-en.txt',
#  '2017BernardSoubryPolicyBrief.txt',
#  'A_Canadian_Opportunity_-_Tackling_climate_change_by_switching_to_clean_power.txt',
#  'Adapting_to_a_Changing_Climate_in_NS.txt',
#  'Ahead-of-the-Storm-1.txt',
#  'AtlanticRegionAdaptationScienceActivitiesReport.txt',
#  'BC-Agriculture-Climate-Change-Action-Plan.txt',
#  'CAT_research_plan_2015.txt',
#  'CCCR_FULLREPORT-EN-FINAL.txt',
#  'ClimatRisk-E-ACCESSIBLE.txt',
#  'En56-226-2008-eng.txt',
#  'FBC_WaterGuide_FINAL.txt',
#  'FloodRecovery-e.txt',
#  'Guide-Building-Sustainable-and-Resilient-Communities-with-Asset-Management-EN.txt',
#  'Guidebook-2016.txt',
#  'HP5-122-2017-eng.txt',
#  'IPCC_SRREN_Ch01.txt',
#  'London_tech.txt',
#  'PB_Are_the_Dutch_going_green.txt',
#  'Perspectives on Climate Change Action in Canada English.txt',
#  'Protect_Your_Home_From_Flooding_Brochure.txt',
#  'Report on Effects of a Changing Climate to the US Department of Defense.txt',
#  'Spring_Flood_Fact_Sheet.txt',
#  'Synthesis_Eng.txt',
#  'Tr045.txt',
#  'UK-CCRA-2017-Synthesis-Report-Committee-on-Climate-Change.txt',
#  'Urban_Forests_Guide.txt',
#  "VOLUME 1 Canada's Changing Climate 2018.txt",
#  'VOLUME 2 Preparing for Change 2018.txt',
#  'VOLUME 3 Creating Resilient Communities 2018.txt',
#  'VOLUME 4 Facing Rising Waters 2018.txt',
#  'Vancouver-Climate-Change-Adaptation-Strategy-2012-11-07.txt',
#  'Vulnerability Guidebook_June2_EN.txt',
#  'WCEL_climate_change_FINAL.txt',
#  'WP_Health_November2008.txt',
#  'Windsor Climate Change Adaptation Plan.txt',
#  'builders_guide_2010_final.txt',
#  'ccp_impactonpeople.txt',
#  'climate_data_discussion_primer.txt',
#  'coastal_flooded_land_guidelines.txt',
#  'env-yukon-state-play-analysis-climate-change-impacts-adaptation.txt',
#  'final_climate_change_and_health_backgrounder_overview.txt',
#  'health_facilit-instal_sante-eng.txt',
#  'info_sheets_summaires.txt',
#  'landuse-e.txt',
#  'municipal-climate-change-action-plan-guidebook-en.txt',
#  'nc6_can_resubmission_english.txt',
#  'nld.txt',
#  'pac_third_report_2019_02_27.txt',
#  'preparedbc_flood_information_for_homeowners_and_home_buyers_2018.txt',
#  'protect-your-home-from-basement-flooding.txt',
#  'public_guideline__principles_of_climate_adaptation_and_mitigation_for_engineers.txt',
#  'sea_dike_guidelines.txt',
#  'slr-primer.txt',
#  'the_london_plan_malp_march_2016_-_chapter_5_-_londons_response_to_climate_change.txt',
#  'waterloo_region_climate_projections_final_revised30oct2015.txt']

# %%
# load the stopwords text file
with open('stopwords.txt','r') as f:
    # create a list for stopwords
    stopwords = []
    # itearate through the text files, replacing any new line unicode characters
    for i in list(f):
        temp = str(i).replace('\n','')
        # append the stopwords to the list
        stopwords.append(temp)

# %%
print(stopwords)
# Out:
# ['Stopwords and Punctuation:', '.', ',', 'and', 'the', 'of', 'to', '-', '/', 'in', '(', ')', 'a', 'for', ':', 'is', 'on', 'or', 'that', 'are', 'be', ').', '1', 'as', 'with', '://', '.,', 'from', '2', 'by', 'www', 'http', 'ca', '[', ']', '...', "'", '\\uf0b7', ';', 'at', ').', 'pdf', 'climate', 'change', 'canada', 'en', '):', 'so', 'html', 'do', '.;', 'com', 'canadian', 'impacts', 'adaptation']

# %%
# change directory to directory with files
os.chdir('/Users/rahimjiwa/Documents/DataScience/UofT3666_AppliedNLP/Final_Testings/tikatextcombined/')
# trying with added new docs

# %%
# create a list for documents
docs = []
# iterate through file list
for i in file_list:
    # load the documents
    text = PlaintextCorpusReader(root=os.getcwd(),fileids=i)
    # create a list of the words in the documents
    i_doc = list(text.words())
    # create a new list for document
    new_i_doc = []
    # for each word in the documents
    for j in i_doc:
        #check if the length of the word is greater than 2 and that it is not a stopword
        if len(j) > 2 and j.lower() not in stopwords:
            # append to word to the new list of words
            new_i_doc.append(j)
    # append list of words to documents
    docs.append(new_i_doc)
    # print the file name
    print(i)
# Out:
# 20170125-en.txt
# 2017BernardSoubryPolicyBrief.txt
# A_Canadian_Opportunity_-_Tackling_climate_change_by_switching_to_clean_power.txt
# Adapting_to_a_Changing_Climate_in_NS.txt
# Ahead-of-the-Storm-1.txt
# AtlanticRegionAdaptationScienceActivitiesReport.txt
# BC-Agriculture-Climate-Change-Action-Plan.txt
# CAT_research_plan_2015.txt
# CCCR_FULLREPORT-EN-FINAL.txt
# ClimatRisk-E-ACCESSIBLE.txt
# En56-226-2008-eng.txt
# FBC_WaterGuide_FINAL.txt
# FloodRecovery-e.txt
# Guide-Building-Sustainable-and-Resilient-Communities-with-Asset-Management-EN.txt
# Guidebook-2016.txt
# HP5-122-2017-eng.txt
# IPCC_SRREN_Ch01.txt
# London_tech.txt
# PB_Are_the_Dutch_going_green.txt
# Perspectives on Climate Change Action in Canada English.txt
# Protect_Your_Home_From_Flooding_Brochure.txt
# Report on Effects of a Changing Climate to the US Department of Defense.txt
# Spring_Flood_Fact_Sheet.txt
# Synthesis_Eng.txt
# Tr045.txt
# UK-CCRA-2017-Synthesis-Report-Committee-on-Climate-Change.txt
# Urban_Forests_Guide.txt
# VOLUME 1 Canada's Changing Climate 2018.txt
# VOLUME 2 Preparing for Change 2018.txt
# VOLUME 3 Creating Resilient Communities 2018.txt
# VOLUME 4 Facing Rising Waters 2018.txt
# Vancouver-Climate-Change-Adaptation-Strategy-2012-11-07.txt
# Vulnerability Guidebook_June2_EN.txt
# WCEL_climate_change_FINAL.txt
# WP_Health_November2008.txt
# Windsor Climate Change Adaptation Plan.txt
# builders_guide_2010_final.txt
# ccp_impactonpeople.txt
# climate_data_discussion_primer.txt
# coastal_flooded_land_guidelines.txt
# env-yukon-state-play-analysis-climate-change-impacts-adaptation.txt
# final_climate_change_and_health_backgrounder_overview.txt
# health_facilit-instal_sante-eng.txt
# info_sheets_summaires.txt
# landuse-e.txt
# municipal-climate-change-action-plan-guidebook-en.txt
# nc6_can_resubmission_english.txt
# nld.txt
# pac_third_report_2019_02_27.txt
# preparedbc_flood_information_for_homeowners_and_home_buyers_2018.txt
# protect-your-home-from-basement-flooding.txt
# public_guideline__principles_of_climate_adaptation_and_mitigation_for_engineers.txt
# sea_dike_guidelines.txt
# slr-primer.txt
# the_london_plan_malp_march_2016_-_chapter_5_-_londons_response_to_climate_change.txt
# waterloo_region_climate_projections_final_revised30oct2015.txt

# %%
# take a look at the output of the documents
docs
# Out:
# [['Clean',
#   'Growth',
#   'PAN',
#   'FRAMEWORK',
#   'Plan',
#   'Address',
#   'Grow',
#   'Economy',
#   'version',
#   'Cat',
#   'En4',
#   '294',
#   '2016E',
#   'ISBN',
#   '978',
#   '660',
#   '07023',
#   'Photos',
#   'Thinkstock',
#   '2016',
#   'Aussi',
#   'disponible',
#   'français',
#   'PAN',
#   'FRAMEWORK',
#   'Clean',
#   'Growth',
#   'Plan',
#   'Address',
#   'Grow',
#   'Economy',
#   'FOREWORD',
#   'Pan',
#   'Framework',
#   'Clean',
#   'Growth',
#   'presented',
#   'here',
#   'our',
#   'collective',
#   'plan',
#   'grow',
#   'our',
#   'economy',
#   'while',
#   'reducing',
#   'emissions',
#   'building',
#   'resilience',
#   'adapt',
#   'changing',
#   'will',
#   'help',
#   'transition',
#   'strong',
#   'diverse',
#   'competitive',
#   'economy',
#   'foster',
#   'job',
#   'creation',
#   'new',
#   'technologies',
#   'exports',
#   'provide',
#   'healthy',
#   'environment',
#   'our',
#   'children',
#   'grandchildren',
#   'Pan',
#   'Framework',
#   'both',
#   'commitment',
#   'world',
#   'will',
#   'its',
#   'part',
#   'plan',
#   'meet',
#   'needs',
#   'Canadians',
#   'have',
#   'built',
#   'momentum',
#   'Paris',
#   'Agreement',
#   'developing',
#   'concrete',
#   'plan',
#   'which',
#   'when',
#   'implemented',
#   'will',
#   'allow',
#   'achieve',
#   'international',
#   'commitments',
#   'When',
#   'First',
#   'Ministers',
#   'met',
#   'last',
#   'March',
#   'Vancouver',
#   'they',
#   'agreed',
#   'take',
#   'ambitious',
#   'action',
#   'support',
#   'meeting',
#   'exceeding',
#   '2030',
#   'target',
#   'percent',
#   'reduction',
#   'below',
#   '2005',
#   'levels',
#   'greenhouse',
#   'gas',
#   'GHG',
#   'emissions',
#   'First',
#   'Ministers',
#   'issued',
#   'Vancouver',
#   'Declaration',
#   'Clean',
#   'Growth',
#   'agreed',
#   'collaborative',
#   'approach',
#   'between',
#   'provincial',
#   'territorial',
#   'federal',
#   'governments',
#   'important',
#   'reduce',
#   'GHG',
#   'emissions',
#   'enable',
#   'sustainable',
#   'economic',
#   'growth',
#   'Pan',
#   'Framework',
#   'builds',
#   'leadership',
#   'shown',
#   'actions',
#   'taken',
#   'individually',
#   'collectively',
#   'provinces',
#   'territories',
#   'including',
#   'through',
#   'Declaration',
#   'Premiers',
#   'adopted',
#   'Quebec',
#   'Summit',
#   '2015',
#   'note',
#   'province',
#   'Saskatchewan',
#   'has',
#   'decided',
#   'not',
#   'adopt',
#   'Pan',
#   'Framework',
#   'this',
#   'time',
#   'federal',
#   'government',
#   'has',
#   'committed',
#   'ensuring',
#   'provinces',
#   'territories',
#   'have',
#   'flexibility',
#   'design',
#   'their',
#   'own',
#   'policies',
#   'programs',
#   'meet',
#   'emission',
#   'reductions',
#   'targets',
#   'supported',
#   'federal',
#   'investments',
#   'infrastructure',
#   'specific',
#   'emission',
#   'reduction',
#   'opportunities',
#   'clean',
#   'technologies',
#   'This',
#   'flexibility',
#   'enables',
#   'governments',
#   'move',
#   'forward',
#   'collaborate',
#   'shared',
#   'priorities',
#   'while',
#   'respecting',
#   'each',
#   'jurisdiction',
#   'needs',
#   'plans',
#   'including',
#   'need',
#   'ensure',
#   'continued',
#   'competitiveness',
#   'viability',
#   'businesses',
#   'Paris',
#   'Agreement',
#   'Parties',
#   'agreed',
#   'they',
#   'should',
#   'when',
#   'taking',
#   'action',
#   'address',
#   'recognize',
#   'respect',
#   'rights',
#   'Indigenous',
#   'Peoples',
#   'implement',
#   'this',
#   'Framework',
#   'will',
#   'move',
#   'forward',
#   'respecting',
#   'rights',
#   'Indigenous',
#   'Peoples',
#   'robust',
#   'meaningful',
#   'engagement',
#   'drawing',
#   'their',
#   'Traditional',
#   'Knowledge',
#   'will',
#   'take',
#   'into',
#   'account',
#   'unique',
#   'circumstances',
#   'opportunities',
#   'Indigenous',
#   'Peoples',
#   'northern',
#   'remote',
#   'vulnerable',
#   'communities',
#   'acknowledge',
#   'thank',
#   'Indigenous',
#   'Peoples',
#   'across',
#   'their',
#   'leadership',
#   'long',
#   'before',
#   'Paris',
#   'Agreement',
#   'being',
#   'active',
#   'drivers',
#   'positive',
#   'Pricing',
#   'carbon',
#   'pollution',
#   'central',
#   'this',
#   'Framework',
#   'Carbon',
#   'pricing',
#   'will',
#   'encourage',
#   'innovation',
#   'because',
#   'businesses',
#   'households',
#   'will',
#   'seek',
#   'out',
#   'new',
#   'ways',
#   'increase',
#   'efficiencies',
#   'pollute',
#   'less',
#   'will',
#   'complement',
#   'carbon',
#   'pricing',
#   'actions',
#   'build',
#   'foundation',
#   'our',
#   'low',
#   'carbon',
#   'resilient',
#   'economy',
#   'transitions',
#   'low',
#   'carbon',
#   'future',
#   'energy',
#   'will',
#   'play',
#   'integral',
#   'role',
#   'meeting',
#   'our',
#   'collective',
#   'commitment',
#   'given',
#   'energy',
#   'production',
#   'use',
#   'account',
#   'over',
#   'percent',
#   'GHG',
#   'emissions',
#   'This',
#   'means',
#   'using',
#   'clean',
#   'energy',
#   'power',
#   'our',
#   'homes',
#   'workplaces',
#   'vehicles',
#   'industries',
#   'using',
#   'energy',
#   'more',
#   'efficiently',
#   'means',
#   'convenient',
#   'transportation',
#   'systems',
#   'run',
#   'cleaner',
#   'fuels',
#   'move',
#   'more',
#   'people',
#   'public',
#   'transit',
#   'zero',
#   'emission',
#   'vehicles',
#   'have',
#   'streamlined',
#   'trade',
#   'corridors',
#   'means',
#   'healthier',
#   'more',
#   'comfortable',
#   'homes',
#   'can',
#   'generate',
#   'Pan',
#   'Framework',
#   'Clean',
#   'Growth',
#   'much',
#   'power',
#   'they',
#   'use',
#   'means',
#   'more',
#   'resilient',
#   'infrastructure',
#   'ecosystems',
#   'can',
#   'better',
#   'withstand',
#   'climatic',
#   'changes',
#   'means',
#   'land',
#   'use',
#   'conservation',
#   'measures',
#   'sequester',
#   'carbon',
#   'foster',
#   'means',
#   'new',
#   'jobs',
#   'Canadians',
#   'across',
#   'country',
#   'opportunities',
#   'growth',
#   'means',
#   'leveraging',
#   'technology',
#   'innovation',
#   'seize',
#   'export',
#   'trade',
#   'opportunities',
#   'which',
#   'will',
#   'allow',
#   'become',
#   'leader',
#   'global',
#   'clean',
#   'growth',
#   'economy',
#   'will',
#   'also',
#   'help',
#   'bring',
#   'down',
#   'cost',
#   'low',
#   'emission',
#   'technologies',
#   'means',
#   'healthier',
#   'communities',
#   'cleaner',
#   'air',
#   'healthy',
#   'diverse',
#   'ecosystems',
#   'across',
#   'country',
#   'will',
#   'maintain',
#   'sustained',
#   'focus',
#   'implementation',
#   'Pan',
#   'Framework',
#   'consistent',
#   'commitment',
#   'under',
#   'Paris',
#   'Agreement',
#   'increase',
#   'level',
#   'ambition',
#   'over',
#   'time',
#   'Pan',
#   'Framework',
#   'historic',
#   'step',
#   'transition',
#   'clean',
#   'growth',
#   'resilient',
#   'economy',
#   'informed',
#   'what',
#   'have',
#   'heard',
#   'Canadians',
#   'will',
#   'continue',
#   'grow',
#   'our',
#   'economy',
#   'create',
#   'good',
#   'jobs',
#   'take',
#   'ambitious',
#   'action',
#   'will',
#   'work',
#   'ensure',
#   'Pan',
#   'Framework',
#   'opens',
#   'new',
#   'opportunities',
#   'businesses',
#   'not',
#   'only',
#   'maintain',
#   'but',
#   'also',
#   'enhance',
#   'their',
#   'competitiveness',
#   'will',
#   'continue',
#   'engage',
#   'Canadians',
#   'strengthen',
#   'deepen',
#   'our',
#   'action',
#   'clean',
#   'growth',
#   'committed',
#   'transparently',
#   'assessing',
#   'reporting',
#   'Canadians',
#   'our',
#   'progress',
#   'Together',
#   'have',
#   'developed',
#   'Pan',
#   'Framework',
#   'Clean',
#   'Growth',
#   'This',
#   'plan',
#   'address',
#   'grow',
#   'clean',
#   'economy',
#   'Pan',
#   'Framework',
#   'Clean',
#   'Growth',
#   'TABLE',
#   'CONTENTS',
#   'INTRODUCTION',
#   '.......................................................................................................................................',
#   'How',
#   'developed',
#   'Framework',
#   '.......................................................................................',
#   'Pillars',
#   'Framework',
#   '.....................................................................................................',
#   'Elements',
#   'collaboration',
#   '...................................................................................................',
#   'Emissions',
#   'trajectory',
#   '2030',
#   '..............................................................................................',
#   'PRICING',
#   'CARBON',
#   'POLLUTION',
#   '...................................................................................................................',
#   'COMPLEMENTARY',
#   'ACTIONS',
#   'REDUCE',
#   'EMISSIONS',
#   '..................................................................................',
#   'Electricity',
#   '.......................................................................................................................',
#   'Built',
#   'environment',
#   '............................................................................................................',
#   'Transportation',
#   '.................................................................................................................',
#   'Industry',
#   '.........................................................................................................................',
#   'Forestry',
#   'agriculture',
#   'waste',
#   '.........................................................................................',
#   'Government',
#   'leadership',
#   '.....................................................................................................',
#   'International',
#   'leadership',
#   '....................................................................................................',
#   'RESILIENCE',
#   '..................................................................................................',
#   'Translating',
#   'scientific',
#   'information',
#   'Traditional',
#   'Knowledge',
#   'into',
#   'action',
#   '...............................',
#   'Building',
#   'resilience',
#   'through',
#   'infrastructure',
#   '...............................................................',
#   'Protecting',
#   'improving',
#   'human',
#   'health',
#   'well',
#   'being',
#   '.......................................................',
#   'Supporting',
#   'particularly',
#   'vulnerable',
#   'regions',
#   '.........................................................................',
#   'Reducing',
#   'related',
#   'hazards',
#   'disaster',
#   'risks',
#   '............................................................',
#   'CLEAN',
#   'TECHNOLOGY',
#   'INNOVATION',
#   'JOBS',
#   '........................................................................................',
#   'Building',
#   'early',
#   'stage',
#   'innovation',
#   '..........................................................................................',
#   'Accelerating',
#   'commercialization',
#   'growth',
#   '........................................................................',
#   'Fostering',
#   'adoption',
#   '...........................................................................................................',
#   'Strengthening',
#   'collaboration',
#   'metrics',
#   'success',
#   '............................................................',
#   'PATHWAY',
#   'MEETING',
#   '2030',
#   'TARGET',
#   '.....................................................................................',
#   'REPORTING',
#   'OVERSIGHT',
#   '.................................................................................................................',
#   'LOOKING',
#   'AHEAD',
#   '....................................................................................................................................',
#   'ANNEX',
#   'FEDERAL',
#   'INVESTMENTS',
#   'MEASURES',
#   'SUPPORT',
#   'TRANSITION',
#   'LOW',
#   'CARBON',
#   'ECONOMY',
#   '........................................................................................................................',
#   'ANNEX',
#   'PROVINCIAL',
#   'TERRITORIAL',
#   'KEY',
#   'ACTIONS',
#   'COLLABORATION',
#   'OPPORTUNITIES',
#   'GOVERNMENT',
#   '..............................................................................................................',
#   'Pan',
#   'Framework',
#   'Clean',
#   'Growth',
#   'Pan',
#   'Framework',
#   'Clean',
#   'Growth',
#   'INTRODUCTION',
#   'abroad',
#   'becoming',
#   'evident',
#   'such',
#   'coastal',
#   'erosion',
#   'thawing',
#   'permafrost',
#   'increases',
#   'heat',
#   'waves',
#   'droughts',
#   'flooding',
#   'risks',
#   'critical',
#   'infrastructure',
#   'food',
#   'security',
#   'already',
#   'being',
#   'felt',
#   'science',
#   'clear',
#   'human',
#   'activities',
#   'driving',
#   'unprecedented',
#   'changes',
#   'Earth',
#   'which',
#   'pose',
#   'significant',
#   'risks',
#   'human',
#   'health',
#   'security',
#   'economic',
#   'growth',
#   'Taking',
#   'strong',
#   'action',
#   'address',
#   'critical',
#   'urgent',
#   'cost',
#   'inaction',
#   'greater',
#   'than',
#   'cost',
#   'action',
#   'could',
#   'cost',
#   'billion',
#   'per',
#   'year',
#   '2050',
#   'according',
#   '2011',
#   'estimates',
#   'National',
#   'Round',
#   'Table',
#   'Environment',
#   'Economy',
#   'Businesses',
#   'markets',
#   'increasingly',
#   'considering',
#   'risks',
#   'recent',
#   'years',
#   'severe',
#   'weather',
#   'events',
#   'have',
#   'cost',
#   'Canadians',
#   'billions',
#   'dollars',
#   'including',
#   'insured',
#   'losses',
#   'Indigenous',
#   'Peoples',
#   'northern',
#   'coastal',
#   'regions',
#   'communities',
#   'particularly',
#   'vulnerable',
#   'disproportionately',
#   'affected',
#   'Geographic',
#   'location',
#   'socio',
#   'economic',
#   'challenges',
#   'Indigenous',
#   'Peoples',
#   'reliance',
#   'wild',
#   'food',
#   'sources',
#   'often',
#   'converge',
#   'put',
#   'pressure',
#   'these',
#   'communities',
#   'Much',
#   'has',
#   'been',
#   'done',
#   'begin',
#   'addressing',
#   'these',
#   'challenges',
#   'including',
#   'Indigenous',
#   'Peoples',
#   'Acting',
#   'will',
#   'reduce',
#   'risks',
#   'create',
#   'new',
#   'economic',
#   'opportunities',
#   'good',
#   'jobs',
#   'Canadians',
#   'There',
#   'already',
#   'global',
#   'market',
#   'low',
#   'carbon',
#   'goods',
#   'services',
#   'worth',
#   'over',
#   'trillion',
#   'which',
#   'projected',
#   'keep',
#   'growing',
#   'rate',
#   'percent',
#   'per',
#   'year',
#   'Clean',
#   'growth',
#   'opportunities',
#   'will',
#   'benefit',
#   'all',
#   'sectors',
#   'regions',
#   'will',
#   'remain',
#   'globally',
#   'competitive',
#   'through',
#   'innovation',
#   'including',
#   'through',
#   'development',
#   'promotion',
#   'innovative',
#   'technologies',
#   'potential',
#   'address',
#   'globally',
#   'This',
#   'includes',
#   'clean',
#   'technology',
#   'enable',
#   'sustainable',
#   'development',
#   'energy',
#   'resource',
#   'sectors',
#   'including',
#   'getting',
#   'these',
#   'resources',
#   'market',
#   'transitions',
#   'low',
#   'carbon',
#   'economy',
#   'Innovation',
#   'can',
#   'help',
#   'further',
#   'reduce',
#   'emissions',
#   'cost',
#   'taking',
#   'action',
#   'home',
#   'technologies',
#   'solutions',
#   'can',
#   'also',
#   'exported',
#   'abroad',
#   'deployed',
#   'around',
#   'world',
#   'creating',
#   'new',
#   'markets',
#   'partners',
#   'businesses',
#   'supporting',
#   'global',
#   'action',
#   'reduce',
#   'emissions',
#   'federal',
#   'government',
#   'will',
#   'continue',
#   'work',
#   'close',
#   'collaboration',
#   'other',
#   'countries',
#   'solutions',
#   'including',
#   'partners',
#   'across',
#   'North',
#   'America',
#   'number',
#   'provinces',
#   'territories',
#   'have',
#   'already',
#   'joined',
#   'exploring',
#   'entry',
#   'into',
#   'regional',
#   'international',
#   'efforts',
#   'reduce',
#   'GHG',
#   'emissions',
#   'Pan',
#   'Framework',
#   'Clean',
#   'Growth',
#   'Pan',
#   'Framework',
#   'Clean',
#   'Growth',
#   'municipalities',
#   'will',
#   'also',
#   'continue',
#   'important',
#   'partners',
#   'developing',
#   'implementing',
#   'solutions',
#   'locally',
#   'well',
#   'through',
#   'international',
#   'collaboration',
#   'other',
#   'municipalities',
#   'around',
#   'world',
#   'international',
#   'community',
#   'has',
#   'agreed',
#   'tackling',
#   'urgent',
#   'priority',
#   'also',
#   'historic',
#   'opportunity',
#   'shift',
#   'towards',
#   'global',
#   'low',
#   'carbon',
#   'economy',
#   'adoption',
#   'Paris',
#   'Agreement',
#   'December',
#   '2015',
#   'was',
#   'culmination',
#   'years',
#   'negotiations',
#   'under',
#   'United',
#   'Nations',
#   'Framework',
#   'Convention',
#   'Paris',
#   'Agreement',
#   'commitment',
#   'accelerate',
#   'intensify',
#   ...],
#  ['eci',
#   'Environmental',
#   'Institute',
#   'Key',
#   'messages',
#   'Maritimes',
#   'food',
#   'system',
#   'vulnerable',
#   'Across',
#   'provincial',
#   'infrastructure',
#   'farms',
#   'food',
#   'system',
#   'vulnerable',
#   'rapid',
#   'well',
#   'long',
#   'term',
#   'changes',
#   'economic',
#   'forces',
#   'These',
#   'vulnerabilities',
#   'can',
#   'impact',
#   'food',
#   'production',
#   'transport',
#   'storage',
#   'consumption',
#   'Farmers',
#   'observations',
#   'match',
#   'projections',
#   'region',
#   'literature',
#   'region',
#   'was',
#   'corroborated',
#   'farmers',
#   'interviewed',
#   'Farmers',
#   'noted',
#   'past',
#   'years',
#   'precipitation',
#   'events',
#   'have',
#   'become',
#   'increasingly',
#   'erratic',
#   'windiness',
#   'has',
#   'increased',
#   'growing',
#   'season',
#   'has',
#   'slowly',
#   'shifted',
#   'later',
#   'into',
#   'autumn',
#   'resilience',
#   'financial',
#   'resilience',
#   'Farmers',
#   'able',
#   'adapt',
#   'their',
#   'practices',
#   'when',
#   'they',
#   'have',
#   'financial',
#   'capacity',
#   'This',
#   'means',
#   'supporting',
#   'markets',
#   'business',
#   'training',
#   'practices',
#   'minimize',
#   'risk',
#   'help',
#   'build',
#   'financial',
#   'resilience',
#   'Building',
#   'adaptive',
#   'capacity',
#   'food',
#   'system',
#   'means',
#   'recognizing',
#   'small',
#   'scale',
#   'farmers',
#   'actors',
#   'their',
#   'own',
#   'right',
#   'Possible',
#   'avenues',
#   'policymakers',
#   'include',
#   'creating',
#   'spaces',
#   'where',
#   'food',
#   'system',
#   'actors',
#   'can',
#   'dialogue',
#   'exchange',
#   'knowledge',
#   'making',
#   'sure',
#   'legislation',
#   'differentiates',
#   'between',
#   'needs',
#   'small',
#   'scale',
#   'farms',
#   'large',
#   'scale',
#   'farms',
#   'promoting',
#   'marketing',
#   'avenues',
#   'which',
#   'distribute',
#   'risk',
#   'open',
#   'new',
#   'markets',
#   'through',
#   'institutions',
#   'like',
#   'operatives',
#   'Food',
#   'Systems',
#   'Maritimes',
#   'Policy',
#   'Brief',
#   'Environmental',
#   'Institute',
#   'University',
#   'Oxford',
#   'July',
#   '2017',
#   'Bernard',
#   'Soubry',
#   'Phil',
#   'Candidate',
#   'Environmental',
#   'Management',
#   'Environmental',
#   'Institute',
#   'concern',
#   'food',
#   'system',
#   'Maritimes',
#   'Coastal',
#   'sea',
#   'level',
#   'rise',
#   'changing',
#   'temperatures',
#   'increasingly',
#   'erratic',
#   'weather',
#   'impact',
#   'way',
#   'food',
#   'produced',
#   'stored',
#   'distributed',
#   'consumed',
#   'Current',
#   'production',
#   'techniques',
#   'responsible',
#   'significant',
#   'part',
#   'greenhouse',
#   'gas',
#   'emissionsi',
#   'this',
#   'way',
#   'agriculture',
#   'both',
#   'cause',
#   'risk',
#   'asked',
#   'farmers',
#   'retailers',
#   'other',
#   'food',
#   'system',
#   'actors',
#   'about',
#   'vulnerability',
#   'food',
#   'system',
#   'Maritimes',
#   'Our',
#   'research',
#   'identifies',
#   'key',
#   'areas',
#   'intervention',
#   'governments',
#   'other',
#   'institutions',
#   'federal',
#   'provincial',
#   'levels',
#   'Integrating',
#   'local',
#   'knowledge',
#   'about',
#   'small',
#   'scale',
#   'producers',
#   'experiences',
#   'will',
#   'help',
#   'inform',
#   'meaningful',
#   'action',
#   'Current',
#   'practices',
#   'must',
#   'towards',
#   'more',
#   'sustainable',
#   'resilient',
#   'production',
#   'order',
#   'safeguard',
#   'Maritime',
#   'food',
#   'system',
#   'This',
#   'briefing',
#   'available',
#   'download',
#   'eci',
#   'Farmer',
#   'Bryan',
#   'Dyck',
#   'checks',
#   'hoophouse',
#   'anchors',
#   'field',
#   'Hoophouses',
#   'flexible',
#   'mobile',
#   'ways',
#   'extending',
#   'season',
#   'but',
#   'they',
#   'vulnerable',
#   'high',
#   'wind',
#   'events',
#   'heavy',
#   'snow',
#   'load',
#   'Photo',
#   'River',
#   'Hébert',
#   'Nova',
#   'Scotia',
#   'May',
#   '2016',
#   'Bernard',
#   'Soubry',
#   'Resilience',
#   'Maritime',
#   'Farms',
#   'Project',
#   'food',
#   'maritimes',
#   'projections',
#   'observations',
#   'Local',
#   'knowledge',
#   'observation',
#   'corroborates',
#   'international',
#   'national',
#   'projections',
#   'IPCC',
#   'SAYS',
#   'FARMERS',
#   'SAY',
#   'Seasonal',
#   'shifts',
#   'towards',
#   'longer',
#   'autumns',
#   'models',
#   'region',
#   'forecast',
#   'shift',
#   'temperatures',
#   'over',
#   'coming',
#   'years',
#   'which',
#   'would',
#   'potentially',
#   'increase',
#   'growing',
#   'seasonii',
#   'Farmers',
#   'observed',
#   'late',
#   'frosts',
#   'getting',
#   'later',
#   'shifting',
#   'growing',
#   'season',
#   'towards',
#   'fall',
#   'Cold',
#   'precipitation',
#   'causing',
#   'issues',
#   'accessing',
#   'land',
#   'early',
#   'season',
#   'maintaining',
#   'farm',
#   'infrastructure',
#   'planning',
#   'market',
#   'More',
#   'erratic',
#   'weather',
#   'precipitation',
#   'modelling',
#   'region',
#   'suggests',
#   'increased',
#   'variability',
#   'precipitation',
#   'over',
#   'time',
#   'More',
#   'erratic',
#   'precipitation',
#   'can',
#   'lead',
#   'drought',
#   'waterlogging',
#   'erosion',
#   'all',
#   'which',
#   'may',
#   'have',
#   'negative',
#   'consequences',
#   'cropsiii',
#   'Farmers',
#   'have',
#   'observed',
#   'significant',
#   'changes',
#   'weather',
#   'patterns',
#   'past',
#   'years',
#   'including',
#   'more',
#   'wind',
#   'events',
#   'potentially',
#   'causing',
#   'damage',
#   'crops',
#   'farm',
#   'infrastructure',
#   'intense',
#   'erratic',
#   'precipitation',
#   'distribution',
#   'channels',
#   'infrastructure',
#   'may',
#   'become',
#   'common',
#   'future',
#   'according',
#   'focused',
#   'Maritimesiv',
#   'Significant',
#   'pockets',
#   'Maritime',
#   'region',
#   'run',
#   'risk',
#   'being',
#   'cut',
#   'off',
#   'otherwise',
#   'significantly',
#   'impacted',
#   'effects',
#   'sea',
#   'level',
#   'rise',
#   'coastal',
#   'erosion',
#   'roads',
#   'other',
#   'protective',
#   'infrastructureiv',
#   'Small',
#   'scale',
#   'producers',
#   'larger',
#   'distributors',
#   'rely',
#   'small',
#   'number',
#   'main',
#   'highways',
#   'distribute',
#   'sell',
#   'their',
#   'produce',
#   'Participants',
#   'interviewed',
#   'worried',
#   'roads',
#   'became',
#   'inaccessible',
#   'food',
#   'distribution',
#   'would',
#   'severely',
#   'impeded',
#   'Table',
#   'Local',
#   'knowledge',
#   'matches',
#   'some',
#   'projections',
#   'made',
#   'global',
#   'modelling',
#   'Farmer',
#   'Shannon',
#   'Jones',
#   'waters',
#   'early',
#   'squash',
#   'greenhouse',
#   'use',
#   'greenhouses',
#   'hoophouses',
#   'extend',
#   'growing',
#   'season',
#   'allows',
#   'farmers',
#   'start',
#   'crops',
#   'much',
#   'earlier',
#   'than',
#   'they',
#   'would',
#   'outdoor',
#   'growing',
#   'conditions',
#   'Photo',
#   'River',
#   'Hébert',
#   'Nova',
#   'Scotia',
#   'May',
#   '2016',
#   'Bernard',
#   'Soubry',
#   'What',
#   'mean',
#   'resilience',
#   'Resilience',
#   'refers',
#   'capacity',
#   'system',
#   'tolerate',
#   'disturbance',
#   'without',
#   'collapsingv',
#   'while',
#   'still',
#   'maintaining',
#   'options',
#   'develop',
#   'Resilience',
#   'theory',
#   'understands',
#   'social',
#   'ecological',
#   'systems',
#   'cannot',
#   'understood',
#   'absence',
#   'each',
#   'othervi',
#   'Resilient',
#   'farm',
#   'resilience',
#   'techniques',
#   'include',
#   'increased',
#   'diversification',
#   'crops',
#   'distribute',
#   'risk',
#   'crop',
#   'failure',
#   'interviews',
#   'farmers',
#   'discussed',
#   'advantages',
#   'growing',
#   'multiple',
#   'varieties',
#   'one',
#   'crop',
#   'selecting',
#   'carefully',
#   'those',
#   'varieties',
#   'which',
#   'produced',
#   'best',
#   'their',
#   'microclimate',
#   'Farmers',
#   'also',
#   'spoke',
#   'soil',
#   'management',
#   'one',
#   'strongest',
#   'ways',
#   'building',
#   'farm',
#   'resilience',
#   'managing',
#   'soil',
#   'promote',
#   'water',
#   'retention',
#   'drainage',
#   'based',
#   'needs',
#   'farm',
#   'farmers',
#   'lessen',
#   'their',
#   'dependence',
#   'organic',
#   'conventional',
#   'fertilizers',
#   'mitigate',
#   'effects',
#   'heavy',
#   'precipitation',
#   'retain',
#   'moisture',
#   'during',
#   'periods',
#   'drought',
#   'How',
#   'farmers',
#   'reacting',
#   'planning',
#   'maritimes',
#   'Small',
#   'scale',
#   'farmers',
#   'Maritimes',
#   'What',
#   'mean',
#   'adaptive',
#   'capacity',
#   'Adaptive',
#   'capacity',
#   'capacity',
#   'make',
#   'changes',
#   'behaviour',
#   'which',
#   'support',
#   'objectives',
#   'like',
#   'healthy',
#   'food',
#   'system',
#   'This',
#   'capacity',
#   'driven',
#   'part',
#   'socioeconomic',
#   'status',
#   'effectiveness',
#   'governance',
#   'institutions',
#   'capacity',
#   'self',
#   'organize',
#   'within',
#   'systemvii',
#   'Adaptive',
#   'Interviews',
#   'revealed',
#   'small',
#   'scale',
#   'farms',
#   'fulfil',
#   'several',
#   'indicators',
#   'high',
#   'adaptive',
#   'capacity',
#   'Some',
#   'examples',
#   'include',
#   'Production',
#   'methods',
#   'varied',
#   'experimental',
#   'Small',
#   'scale',
#   'agriculture',
#   'adaptive',
#   'flexible',
#   'nature',
#   'Farmers',
#   'Maritimes',
#   'have',
#   'been',
#   'experimenting',
#   'season',
#   'extension',
#   'infrastructure',
#   'crop',
#   'varieties',
#   'market',
#   'gardening',
#   'techniques',
#   'They',
#   'can',
#   'exchange',
#   'information',
#   'experiment',
#   'results',
#   'gatherings',
#   'Farmers',
#   'discussed',
#   'idea',
#   'financial',
#   'resilience',
#   'face',
#   'making',
#   'their',
#   'businesses',
#   'less',
#   'susceptible',
#   'changes',
#   'market',
#   'consumer',
#   'preferences',
#   'Examples',
#   'financial',
#   'resilience',
#   'include',
#   'marketing',
#   'operatives',
#   'which',
#   'prominent',
#   'New',
#   'Brunswick',
#   'community',
#   'supported',
#   'agriculture',
#   'CSA',
#   'schemes',
#   'Marketing',
#   'operatives',
#   'key',
#   'maintaining',
#   'share',
#   'market',
#   'small',
#   'farmers',
#   'well',
#   'distributing',
#   'financial',
#   'risk',
#   'between',
#   'farms',
#   'CSAs',
#   'stabilize',
#   'cash',
#   'flow',
#   'asking',
#   'customers',
#   'pay',
#   'season',
#   'worth',
#   'produce',
#   'advance',
#   'give',
#   'farmers',
#   'better',
#   'idea',
#   'demand',
#   'thereby',
#   'lowering',
#   'risk',
#   'overproduction',
#   'form',
#   'strong',
#   'social',
#   'bonds',
#   'customers',
#   'strong',
#   'social',
#   'network',
#   'formal',
#   'informal',
#   'adaptive',
#   'institutions',
#   'Farmers',
#   'spoke',
#   'closeness',
#   'farming',
#   'community',
#   'Maritimes',
#   'Given',
#   'there',
#   'relatively',
#   'few',
#   'small',
#   'farms',
#   'each',
#   'region',
#   'possible',
#   'information',
#   'move',
#   'very',
#   'quickly',
#   'between',
#   'farms',
#   'advice',
#   'help',
#   'come',
#   'quickly',
#   'when',
#   'needed',
#   'Acceptance',
#   'future',
#   'will',
#   'volatile',
#   'Dealing',
#   'uncertainty',
#   'basic',
#   'reality',
#   'farming',
#   'Maritimes',
#   'Maritime',
#   'farmers',
#   'spoke',
#   'about',
#   'ensuring',
#   'any',
#   'investment',
#   'they',
#   'make',
#   'will',
#   'able',
#   'adapt',
#   'changes',
#   'resilient',
#   'shocks',
#   'surprises',
#   'Vulnerable',
#   'interviews',
#   'farmers',
#   'identified',
#   'several',
#   'vulnerabilities',
#   'their',
#   'businesses',
#   'food',
#   'producers',
#   'well',
#   'food',
#   'system',
#   'general',
#   'Farmers',
#   'were',
#   'concerned',
#   'lack',
#   'adequate',
#   'infrastructure',
#   'transportation',
#   'storage',
#   'distribution',
#   'food',
#   'across',
#   'Maritimes',
#   'Key',
#   'transportation',
#   'routes',
#   'risk',
#   'being',
#   'affected',
#   'sea',
#   'level',
#   'rise',
#   'storms',
#   'which',
#   'would',
#   'turn',
#   'affect',
#   'farmers',
#   'ability',
#   'market',
#   'distributors',
#   'bring',
#   'produce',
#   'stores',
#   'They',
#   'also',
#   'mentioned',
#   'lack',
#   'distribution',
#   'processing',
#   'storage',
#   'infrastructure',
#   'across',
#   'regions',
#   'which',
#   'leaves',
#   'individual',
#   'farms',
#   'vulnerable',
#   'storms',
#   'makes',
#   'processing',
#   'meat',
#   'difficult',
#   'costly',
#   'process',
#   'Many',
#   'small',
#   'farmers',
#   'lack',
#   'trust',
#   'governance',
#   'institutions',
#   'This',
#   'lack',
#   'trust',
#   'was',
#   'traced',
#   'back',
#   'feeling',
#   'such',
#   'institutions',
#   'primarily',
#   'existed',
#   'represent',
#   'interests',
#   'large',
#   'scale',
#   'agriculture',
#   'Support',
#   'which',
#   'would',
#   'otherwise',
#   'available',
#   'small',
#   'farms',
#   'often',
#   'rejected',
#   'due',
#   'dislike',
#   'bureaucracy',
#   'lack',
#   'understanding',
#   'regards',
#   'opportunities',
#   'What',
#   'mean',
#   'vulnerability',
#   'Intergovernmental',
#   'Panel',
#   'defines',
#   'vulnerability',
#   'degree',
#   'which',
#   'geophysical',
#   'biological',
#   'socio',
#   'economic',
#   'systems',
#   'susceptible',
#   'unable',
#   'cope',
#   'adverse',
#   'viii',
#   'includes',
#   'factors',
#   'which',
#   'may',
#   'enhance',
#   'deter',
#   'adaptive',
#   'capacity',
#   'Barriers',
#   'Lack',
#   'provincial',
#   'planning',
#   'food',
#   'system',
#   'There',
#   'currently',
#   'explicit',
#   'public',
#   'provincial',
#   'strategy',
#   'food',
#   'systems',
#   'New',
#   'Brunswick',
#   'Nova',
#   'Scotia',
#   'Prince',
#   'Edward',
#   'Island',
#   'Without',
#   'proper',
#   'consideration',
#   'government',
#   'food',
#   'systems',
#   'will',
#   'difficult',
#   'develop',
#   'quickly',
#   'effectively',
#   'Lack',
#   'unified',
#   'planning',
#   'federal',
#   'provincial',
#   'levels',
#   'negatively',
#   'adaptive',
#   'capacity',
#   'actors',
#   'across',
#   'food',
#   'system',
#   'impeding',
#   'financial',
#   'support',
#   'knowledge',
#   'exchange',
#   'Weak',
#   'support',
#   'networks',
#   'between',
#   'farmers',
#   'governance',
#   'institutions',
#   'Many',
#   'small',
#   'farmers',
#   'across',
#   'Maritimes',
#   'suggested',
#   'they',
#   ...],
#  ['CEC',
#   'Electrification',
#   'New',
#   'V3_1',
#   'Opportunity',
#   'Tackling',
#   'switching',
#   'clean',
#   'power',
#   'Opportunity',
#   'Tackling',
#   'switching',
#   'clean',
#   'power',
#   'Opportunity',
#   'Tackling',
#   'switching',
#   'clean',
#   'power',
#   'June',
#   '2016',
#   'Opportunity',
#   'Tackling',
#   'switching',
#   'clean',
#   'power',
#   'Arriving',
#   'Opportunity',
#   'March',
#   '2016',
#   'Premiers',
#   'Prime',
#   'Minister',
#   'launched',
#   'unprecedented',
#   'initiative',
#   'they',
#   'agreed',
#   'work',
#   'together',
#   'reach',
#   'national',
#   'plan',
#   'adoption',
#   'early',
#   '2017',
#   'federal',
#   'provincial',
#   'officials',
#   'working',
#   'hard',
#   'develop',
#   'policy',
#   'options',
#   'was',
#   'clear',
#   'window',
#   'had',
#   'opened',
#   'join',
#   'hopefully',
#   'influence',
#   'national',
#   'conversation',
#   'Clean',
#   'Energy',
#   'believed',
#   'set',
#   'policy',
#   'recommendations',
#   'backed',
#   'coalition',
#   'stakeholders',
#   'various',
#   'sectors',
#   'would',
#   'carry',
#   'more',
#   'weight',
#   'than',
#   'any',
#   'contribution',
#   'could',
#   'make',
#   'our',
#   'own',
#   'convened',
#   'representative',
#   'group',
#   'stakeholders',
#   'experts',
#   'crucial',
#   'issue',
#   'electrification',
#   'person',
#   'meeting',
#   'Ottawa',
#   'May',
#   'advance',
#   'meeting',
#   'Clean',
#   'Energy',
#   'performed',
#   'review',
#   'relevant',
#   'literature',
#   'electrification',
#   'interviewed',
#   'virtually',
#   'all',
#   'participants',
#   'understand',
#   'their',
#   'perspective',
#   'test',
#   'areas',
#   'convergence',
#   'produced',
#   'discussion',
#   'paper',
#   'listing',
#   'policy',
#   'options',
#   'discussion',
#   'worked',
#   'SFU',
#   'Centre',
#   'Dialogue',
#   'shape',
#   'effective',
#   'agenda',
#   'facilitation',
#   'roundtable',
#   'federal',
#   'provincial',
#   'officials',
#   'working',
#   'hard',
#   'develop',
#   'policy',
#   'options',
#   'was',
#   'clear',
#   'window',
#   'had',
#   'opened',
#   'join',
#   'hopefully',
#   'influence',
#   'national',
#   'conversation',
#   'Contents',
#   'Signatories',
#   'Introduction',
#   'Supportive',
#   'Policies',
#   'Electrification',
#   'Transportation',
#   'Buildings',
#   'Industrial',
#   'Processes',
#   'Electricity',
#   'Supply',
#   'Minister',
#   'Environment',
#   'Catherine',
#   'McKenna',
#   'opened',
#   'roundtable',
#   'She',
#   'stressed',
#   'power',
#   'coalitions',
#   'unusual',
#   'suspects',
#   'collaborating',
#   'policy',
#   'solutions',
#   'emphasized',
#   'importance',
#   'electrification',
#   'solution',
#   'May',
#   'roundtable',
#   'was',
#   'very',
#   'successful',
#   'all',
#   'participants',
#   'expressed',
#   'interest',
#   'continuing',
#   'work',
#   'package',
#   'policy',
#   'recommendations',
#   'formal',
#   'submission',
#   'federal',
#   'provincial',
#   'process',
#   'Clean',
#   'Energy',
#   'staff',
#   'worked',
#   'roundtable',
#   'participants',
#   'often',
#   'one',
#   'one',
#   'produce',
#   'set',
#   'consensus',
#   'policy',
#   'recommendations',
#   'policy',
#   'package',
#   'has',
#   'already',
#   'been',
#   'favourably',
#   'received',
#   'officials',
#   'involved',
#   'development',
#   'national',
#   'plan',
#   'but',
#   'see',
#   'just',
#   'first',
#   'step',
#   'will',
#   'working',
#   'signatories',
#   'this',
#   'document',
#   'well',
#   'wider',
#   'group',
#   'stakeholders',
#   'over',
#   'weeks',
#   'months',
#   'come',
#   'advance',
#   'policy',
#   'recommendations',
#   'proposed',
#   'here',
#   'Our',
#   'thanks',
#   'Shauna',
#   'Sylvester',
#   'director',
#   'SFU',
#   'Centre',
#   'Dialogue',
#   'her',
#   'facilitation',
#   'expertise',
#   'Sustainable',
#   'Prosperity',
#   'hosting',
#   'event',
#   'Opportunity',
#   'Tackling',
#   'switching',
#   'clean',
#   'power',
#   'Signatories',
#   'Opportunity',
#   'Tackling',
#   'switching',
#   'clean',
#   'power',
#   'Chris',
#   'Bataille',
#   'IDDRI',
#   'org',
#   'Simon',
#   'Fraser',
#   'University',
#   'Jose',
#   'Etcheverry',
#   'Sustainable',
#   'Energy',
#   'Initiative',
#   'York',
#   'University',
#   'David',
#   'Runnalls',
#   'Institute',
#   'Environment',
#   'University',
#   'Ottawa',
#   'Individual',
#   'Signatories',
#   'Signatories',
#   'ACTION',
#   'NETWORK',
#   'RacCAN',
#   'RÉSEAU',
#   'ACTION',
#   'CLIMAT',
#   'Opportunity',
#   'Tackling',
#   'switching',
#   'clean',
#   'power',
#   'Electrification',
#   'ACTION',
#   'Advanced',
#   'Meter',
#   'Smart',
#   'Charging',
#   'Local',
#   'Energy',
#   'Generation',
#   'Heat',
#   'Pump',
#   'Time',
#   'Varying',
#   'Rates',
#   'Smart',
#   'Appliances',
#   'High',
#   'Efficiency',
#   'Homes',
#   'Renewable',
#   'Power',
#   'Generation',
#   'Source',
#   'Adapted',
#   'Acadia',
#   'Centre',
#   'EnergyVision',
#   '2014',
#   'Introduction',
#   'Expert',
#   'assessments',
#   'clear',
#   'tackle',
#   'need',
#   'clean',
#   'electricity',
#   'power',
#   'far',
#   'more',
#   'our',
#   'daily',
#   'activities',
#   'than',
#   'does',
#   'today',
#   'even',
#   'factoring',
#   'dramatic',
#   'improvement',
#   'energy',
#   'productivity',
#   'Over',
#   'time',
#   'will',
#   'need',
#   'shift',
#   'fuelling',
#   'our',
#   'personal',
#   'vehicles',
#   'gasoline',
#   'driving',
#   'electric',
#   'cars',
#   'Electric',
#   'pumps',
#   'will',
#   'draw',
#   'heat',
#   'air',
#   'ground',
#   'keep',
#   'our',
#   'homes',
#   'warm',
#   'winter',
#   'cool',
#   'summer',
#   'Innovative',
#   'industrial',
#   'processes',
#   'will',
#   'produce',
#   'goods',
#   'materials',
#   'need',
#   'using',
#   'clean',
#   'power',
#   'rather',
#   'than',
#   'fossil',
#   'fuels',
#   'growing',
#   'interconnectivity',
#   'internet',
#   'electricity',
#   'generation',
#   'consumption',
#   'will',
#   'also',
#   'make',
#   'these',
#   'power',
#   'flows',
#   'smarter',
#   'tackle',
#   'need',
#   'clean',
#   'electricity',
#   'power',
#   'far',
#   'more',
#   'our',
#   'daily',
#   'activities',
#   'than',
#   'does',
#   'today',
#   'Opportunity',
#   'Tackling',
#   'switching',
#   'clean',
#   'power',
#   'This',
#   'shift',
#   'fossil',
#   'fuels',
#   'clean',
#   'electricity',
#   'needed',
#   'but',
#   'even',
#   'larger',
#   'extent',
#   'around',
#   'world',
#   'While',
#   'not',
#   'one',
#   'size',
#   'fits',
#   'all',
#   'solution',
#   'electrification',
#   'will',
#   'big',
#   'part',
#   'international',
#   'effort',
#   'live',
#   'commitments',
#   'countries',
#   'made',
#   'talks',
#   'Paris1',
#   'result',
#   'global',
#   'market',
#   'clean',
#   'electricity',
#   'growing',
#   'quickly',
#   'demand',
#   'technologies',
#   'services',
#   'underpin',
#   'electric',
#   'transportation',
#   'buildings',
#   'industrial',
#   'processes',
#   'smart',
#   'grids',
#   'excellent',
#   'news',
#   'our',
#   'country',
#   'already',
#   'has',
#   'one',
#   'cleanest',
#   'electricity',
#   'sectors',
#   'world',
#   'Today',
#   'well',
#   'over',
#   'per',
#   'cent',
#   'our',
#   'power',
#   'comes',
#   'water',
#   'wind',
#   'sun',
#   'share',
#   'renewable',
#   'electricity',
#   'poised',
#   'grow',
#   'thanks',
#   'government',
#   'commitments',
#   'further',
#   'decarbonize',
#   'power',
#   'supply',
#   'ambitious',
#   'effective',
#   'policies',
#   'headstart',
#   'means',
#   'our',
#   'country',
#   'positioned',
#   'reach',
#   'near',
#   'zero',
#   'emission',
#   'power',
#   'well',
#   'ahead',
#   'its',
#   'peers',
#   'other',
#   'words',
#   'clean',
#   'electricity',
#   'comparative',
#   'advantage',
#   'one',
#   'positions',
#   'lead',
#   'global',
#   'clean',
#   'energy',
#   'economy',
#   'right',
#   'policy',
#   'signals',
#   'foundation',
#   'our',
#   'country',
#   'can',
#   'reap',
#   'benefits',
#   'rapid',
#   'shift',
#   'clean',
#   'electricity',
#   'source',
#   'energy',
#   'across',
#   'economy',
#   'see',
#   'those',
#   'benefits',
#   'new',
#   'jobs',
#   'innovation',
#   'business',
#   'development',
#   'export',
#   'opportunities',
#   'while',
#   'reducing',
#   'our',
#   'carbon',
#   'pollution',
#   'This',
#   'document',
#   'frames',
#   'some',
#   'most',
#   'important',
#   'policy',
#   'choices',
#   'governments',
#   'can',
#   'make',
#   'into',
#   'strategy',
#   'accelerate',
#   'shift',
#   'clean',
#   'electricity',
#   'energy',
#   'source',
#   'economy',
#   'recognise',
#   'this',
#   'strategy',
#   'must',
#   'about',
#   'transforming',
#   'transportation',
#   'buildings',
#   'industrial',
#   'processes',
#   'much',
#   'electricity',
#   'generation',
#   'sector',
#   'itself',
#   'also',
#   'describe',
#   'overarching',
#   'policies',
#   'needed',
#   'support',
#   'electrification',
#   'foundation',
#   'clean',
#   'innovative',
#   'economy',
#   'hope',
#   'policy',
#   'recommendations',
#   'listed',
#   'below',
#   'useful',
#   'you',
#   'craft',
#   'pan',
#   'plan',
#   'welcome',
#   'any',
#   'questions',
#   'comments',
#   'you',
#   'may',
#   'have',
#   'look',
#   'forward',
#   'working',
#   'you',
#   'weeks',
#   'months',
#   'ahead',
#   'Original',
#   'Signatories',
#   'Merran',
#   'Smith',
#   'Clean',
#   'Energy',
#   'Cara',
#   'Clairman',
#   'Plug',
#   'Drive',
#   'Louise',
#   'Comeau',
#   'Conservation',
#   'Council',
#   'New',
#   'Brunswick',
#   'Ron',
#   'Dizy',
#   'Advanced',
#   'Energy',
#   'Centre',
#   'MaRS',
#   'John',
#   'Gorman',
#   'Solar',
#   'Industries',
#   'Association',
#   'CanSIA',
#   'Chantal',
#   'Guimond',
#   'Electric',
#   'Mobility',
#   'Chris',
#   'Henderson',
#   'Lumos',
#   'Energy',
#   'Principal',
#   'Clean',
#   'Energy',
#   'Advisor',
#   'Indigenous',
#   'Peoples',
#   'Robert',
#   'Hornung',
#   'Wind',
#   'Energy',
#   'Association',
#   'CanWEA',
#   'Jacob',
#   'Irving',
#   'Hydropower',
#   'Association',
#   'Paul',
#   'Kariya',
#   'Clean',
#   'Energy',
#   'Elisa',
#   'Obermann',
#   'Marine',
#   'Renewables',
#   'Pembina',
#   'Institute',
#   'Félix',
#   'Boudreault',
#   'Principal',
#   'Advisors',
#   'Dave',
#   'Sawyer',
#   'EnviroEconomics',
#   'David',
#   'Runnalls',
#   'Visiting',
#   'Professor',
#   'Institute',
#   'Environment',
#   'University',
#   'Ottawa',
#   'right',
#   'policy',
#   'signals',
#   'foundation',
#   'our',
#   'country',
#   'can',
#   'reap',
#   'benefits',
#   'rapid',
#   'shift',
#   'clean',
#   'electricity',
#   'source',
#   'energy',
#   'across',
#   'economy',
#   'See',
#   'IPCC',
#   '2014',
#   'Summary',
#   'Policymakers',
#   '2014',
#   'Mitigation',
#   'Contribution',
#   'Working',
#   'Group',
#   'III',
#   'Fifth',
#   'Assessment',
#   'Report',
#   'Intergovernmental',
#   'Panel',
#   'ipcc',
#   'assessment',
#   'report',
#   'ar5',
#   'wg3',
#   'ipcc_wg3_ar5_',
#   'summary',
#   'policymakers',
#   'Opportunity',
#   'Tackling',
#   'switching',
#   'clean',
#   'power',
#   'Supportive',
#   'Policies',
#   'Electrification',
#   'While',
#   'policies',
#   'described',
#   'this',
#   'section',
#   'may',
#   'not',
#   'result',
#   'directly',
#   'switch',
#   'fossil',
#   'fuels',
#   'clean',
#   'power',
#   'they',
#   'lay',
#   'groundwork',
#   'electrification',
#   'transition',
#   'needs',
#   'accelerate',
#   'rapidly',
#   'meet',
#   'our',
#   '2030',
#   'goal',
#   'but',
#   'also',
#   'very',
#   'long',
#   'term',
#   'effort',
#   'Policies',
#   'support',
#   'durable',
#   'effective',
#   'transition',
#   'electrification',
#   'include',
#   'price',
#   'carbon',
#   'across',
#   'price',
#   'signal',
#   'should',
#   'apply',
#   'all',
#   'jurisdictions',
#   'start',
#   'quickly',
#   'possible',
#   'where',
#   'doesn',
#   'exist',
#   'already',
#   'grow',
#   'over',
#   'time',
#   'cover',
#   'vast',
#   'majority',
#   'emissions',
#   'national',
#   'roadmap',
#   'action',
#   'plan',
#   'electrification',
#   'Electrification',
#   'remains',
#   'relatively',
#   'new',
#   'policy',
#   'area',
#   'faces',
#   'some',
#   'significant',
#   'barriers',
#   'roadmap',
#   'electrification',
#   'would',
#   'help',
#   'fill',
#   'information',
#   'gaps',
#   'exist',
#   'today',
#   'lay',
#   'out',
#   'national',
#   'vision',
#   'aligned',
#   'pan',
#   'effort',
#   'tackle',
#   'Council',
#   'Federation',
#   'Energy',
#   'Strategy',
#   'national',
#   'action',
#   'plan',
#   'electrification',
#   'should',
#   'also',
#   'include',
#   'national',
#   'goal',
#   'reaching',
#   'near',
#   'zero',
#   'carbon',
#   'electricity',
#   'supply',
#   'given',
#   'year',
#   'along',
#   'interim',
#   'milestones',
#   'electricity',
#   'sector',
#   'should',
#   'demonstrate',
#   'continuously',
#   'decreasing',
#   'GHG',
#   'emissions',
#   'while',
#   'ensuring',
#   'reliability',
#   'affordability',
#   'power',
#   'supplies',
#   'support',
#   'national',
#   'electricity',
#   'sector',
#   'goal',
#   'assessments',
#   'growth',
#   'clean',
#   'power',
#   'supply',
#   'will',
#   'required',
#   'various',
#   'regions',
#   'plans',
#   'meet',
#   'those',
#   'needs',
#   'Sector',
#   'sector',
#   'electrification',
#   'goals',
#   'pathways',
#   'end',
#   'use',
#   'sectors',
#   'transportation',
#   'buildings',
#   'industry',
#   'etc',
#   'short',
#   'medium',
#   'long',
#   'term',
#   'Assessments',
#   'including',
#   'cost',
#   'benefit',
#   'analysis',
#   'grid',
#   'modernization',
#   'will',
#   'needed',
#   'plans',
#   'achieve',
#   'those',
#   'improvements',
#   'recognizing',
#   'advantage',
#   'economic',
#   'value',
#   'potential',
#   'electricity',
#   'storage',
#   'capacity',
#   'hydro',
#   'reservoirs',
#   'well',
#   'smaller',
#   'scale',
#   'storage',
#   'distributed',
#   'generation',
#   'Investments',
#   'smart',
#   'grids',
#   'micro',
#   'grids',
#   'will',
#   'allow',
#   'more',
#   'efficient',
#   'use',
#   'electricity',
#   'greater',
#   'integration',
#   'decentralized',
#   'power',
#   'while',
#   'maintaining',
#   'reliability',
#   'resilience',
#   'especially',
#   'face',
#   'changing',
#   'affordability',
#   'consumers',
#   'Assessments',
#   'financing',
#   'needs',
#   'associated',
#   'electrification',
#   ...],
#  ['None'],
#  ['Natalia',
#   'Moudrak',
#   'Blair',
#   'Feltmate',
#   'Intact',
#   'Centre',
#   'AHEAD',
#   'STORM',
#   'SUPPORTED',
#   'Developing',
#   'Flood',
#   'Resilience',
#   'Guidance',
#   'Commercial',
#   'Real',
#   'Estate',
#   'October',
#   '2019',
#   'Ahead',
#   'Storm',
#   'Developing',
#   'Flood',
#   'Resilience',
#   'Guidance',
#   'Commercial',
#   'Real',
#   'Estate2',
#   'AHEAD',
#   'STORM',
#   'Ahead',
#   'Storm',
#   'Developing',
#   'Flood',
#   'Resilience',
#   'Guidance',
#   'Commercial',
#   'Real',
#   'Estate',
#   'About',
#   'Intact',
#   'Centre',
#   'Intact',
#   'Centre',
#   'Intact',
#   'Centre',
#   'applied',
#   'research',
#   'centre',
#   'University',
#   'Waterloo',
#   'Intact',
#   'Centre',
#   'was',
#   'founded',
#   '2015',
#   'gift',
#   'Intact',
#   'Financial',
#   'Corporation',
#   'largest',
#   'property',
#   'casualty',
#   'insurer',
#   'Intact',
#   'Centre',
#   'helps',
#   'homeowners',
#   'communities',
#   'businesses',
#   'reduce',
#   'risks',
#   'associated',
#   'extreme',
#   'weather',
#   'events',
#   'additional',
#   'information',
#   'visit',
#   'intactcentreclimateadaptation',
#   'About',
#   'University',
#   'Waterloo',
#   'University',
#   'Waterloo',
#   'top',
#   'innovation',
#   'university',
#   'more',
#   'than',
#   '000',
#   'students',
#   'university',
#   'home',
#   'world',
#   'largest',
#   'operative',
#   'education',
#   'system',
#   'its',
#   'kind',
#   'university',
#   'unmatched',
#   'entrepreneurial',
#   'culture',
#   'combined',
#   'intensive',
#   'focus',
#   'research',
#   'powers',
#   'one',
#   'top',
#   'innovation',
#   'hubs',
#   'world',
#   'additional',
#   'information',
#   'visit',
#   'uwaterloo',
#   'About',
#   'REALPAC',
#   'Real',
#   'Property',
#   'Association',
#   'REALPAC',
#   'senior',
#   'industry',
#   'association',
#   'owners',
#   'managers',
#   'investment',
#   'real',
#   'estate',
#   'Our',
#   'members',
#   'include',
#   'publicly',
#   'traded',
#   'real',
#   'estate',
#   'companies',
#   'real',
#   'estate',
#   'investment',
#   'trusts',
#   'REIT',
#   'private',
#   'companies',
#   'pension',
#   'funds',
#   'fund',
#   'managers',
#   'banks',
#   'life',
#   'insurance',
#   'companies',
#   'cumulative',
#   'real',
#   'estate',
#   'assets',
#   'under',
#   'management',
#   'between',
#   '600',
#   'Billion',
#   'Trillion',
#   'CAD',
#   'association',
#   'further',
#   'supported',
#   'large',
#   'owner',
#   'occupiers',
#   'pension',
#   'fund',
#   'advisors',
#   'well',
#   'individually',
#   'selected',
#   'investment',
#   'dealers',
#   'real',
#   'estate',
#   'brokerages',
#   'additional',
#   'information',
#   'visit',
#   'realpac',
#   'About',
#   'BOMA',
#   'Comprised',
#   'over',
#   '100',
#   'members',
#   'BOMA',
#   'oldest',
#   'commercial',
#   'real',
#   'estate',
#   'industry',
#   'association',
#   'members',
#   'own',
#   'manage',
#   'over',
#   'billion',
#   'square',
#   'feet',
#   'commercial',
#   'space',
#   'include',
#   'building',
#   'owners',
#   'managers',
#   'developers',
#   'facilities',
#   'managers',
#   'asset',
#   'managers',
#   'leasing',
#   'agents',
#   'brokers',
#   'investors',
#   'vendors',
#   'service',
#   'providers',
#   'Together',
#   'its',
#   'eleven',
#   'chapters',
#   'BOMA',
#   'represents',
#   'commercial',
#   'real',
#   'estate',
#   'industry',
#   'matters',
#   'national',
#   'international',
#   'concern',
#   'provides',
#   'industry',
#   'leading',
#   'programs',
#   'such',
#   'bomabest',
#   'org',
#   'principal',
#   'sustainability',
#   'certification',
#   'commercial',
#   'real',
#   'estate',
#   'additional',
#   'information',
#   'visit',
#   'bomacanada',
#   'About',
#   'Intact',
#   'Financial',
#   'Corporation',
#   'Intact',
#   'Financial',
#   'Corporation',
#   'TSX',
#   'IFC',
#   'largest',
#   'provider',
#   'property',
#   'casualty',
#   'insurance',
#   'leading',
#   'provider',
#   'specialty',
#   'insurance',
#   'North',
#   'America',
#   'over',
#   'billion',
#   'total',
#   'annual',
#   'premiums',
#   'Company',
#   'has',
#   'approximately',
#   '000',
#   'full',
#   'part',
#   'time',
#   'employees',
#   'who',
#   'serve',
#   'more',
#   'than',
#   'five',
#   'million',
#   'personal',
#   'business',
#   'public',
#   'sector',
#   'clients',
#   'through',
#   'offices',
#   'Intact',
#   'distributes',
#   'insurance',
#   'under',
#   'Intact',
#   'Insurance',
#   'brand',
#   'through',
#   'wide',
#   'network',
#   'brokers',
#   'including',
#   'its',
#   'wholly',
#   'owned',
#   'subsidiary',
#   'BrokerLink',
#   'directly',
#   'consumers',
#   'through',
#   'belairdirect',
#   'OneBeacon',
#   'Insurance',
#   'Group',
#   'wholly',
#   'owned',
#   'subsidiary',
#   'provides',
#   'specialty',
#   'insurance',
#   'products',
#   'through',
#   'independent',
#   'agencies',
#   'brokers',
#   'wholesalers',
#   'managing',
#   'general',
#   'agencies',
#   'additional',
#   'information',
#   'visit',
#   'intactfc',
#   'Citation',
#   'Moudrak',
#   'Feltmate',
#   '2019',
#   'Ahead',
#   'Storm',
#   'Developing',
#   'Flood',
#   'Resilience',
#   'Guidance',
#   'Commercial',
#   'Real',
#   'Estate',
#   'Prepared',
#   'REALPAC',
#   'BOMA',
#   'Intact',
#   'Centre',
#   'University',
#   'Waterloo',
#   'information',
#   'about',
#   'this',
#   'report',
#   'contact',
#   'Natalia',
#   'Moudrak',
#   'nmoudrak',
#   'uwaterloo',
#   'Disclaimer',
#   'information',
#   'stated',
#   'this',
#   'report',
#   'has',
#   'best',
#   'our',
#   'knowledge',
#   'been',
#   'collected',
#   'verified',
#   'much',
#   'possible',
#   'Intact',
#   'Centre',
#   'cannot',
#   'make',
#   'any',
#   'guarantees',
#   'any',
#   'kind',
#   'completeness',
#   'accuracy',
#   'suitability',
#   'reliability',
#   'data',
#   'provided',
#   'report',
#   'This',
#   'report',
#   'has',
#   'been',
#   'prepared',
#   'general',
#   'guidance',
#   'matters',
#   'interest',
#   'only',
#   'does',
#   'not',
#   'constitute',
#   'professional',
#   'advice',
#   'You',
#   'should',
#   'not',
#   'act',
#   'upon',
#   'information',
#   'contained',
#   'this',
#   'publication',
#   'without',
#   'obtaining',
#   'specific',
#   'professional',
#   'advice',
#   'representation',
#   'warranty',
#   'express',
#   'implied',
#   'given',
#   'accuracy',
#   'completeness',
#   'information',
#   'contained',
#   'this',
#   'publication',
#   'Intact',
#   'Centre',
#   'employees',
#   'affiliates',
#   'not',
#   'accept',
#   'assume',
#   'any',
#   'liability',
#   'responsibility',
#   'duty',
#   'care',
#   'any',
#   'consequences',
#   'you',
#   'anyone',
#   'else',
#   'acting',
#   'refraining',
#   'act',
#   'reliance',
#   'information',
#   'contained',
#   'this',
#   'report',
#   'any',
#   'decision',
#   'based',
#   'upon',
#   'intactcentreclimateadaptation',
#   'uwaterloo',
#   'realpac',
#   'bomacanada',
#   'intactfc',
#   'mailto',
#   'nmoudrak',
#   '40uwaterloo',
#   'subject',
#   'Information',
#   '20Request',
#   '20Flood',
#   '20Resilience',
#   '20Guide',
#   'Ahead',
#   'Storm',
#   'Developing',
#   'Flood',
#   'Resilience',
#   'Guidance',
#   'Commercial',
#   'Real',
#   'Estate4',
# ...
#   'existing',
#   'building',
#   'stock',
#   'moving',
#   'towards',
#   'zero',
#   'emission',
#   'transport',
#   'London',
#   'see',
#   'also',
#   'Chapter',
#   'Mayor',
#   'Transport',
#   'Strategy',
#   '179',
#   'world',
#   'eighth',
#   'largest',
#   'emitter',
#   'carbon',
#   'dioxide',
#   'London',
#   'responsible',
#   'per',
#   'cent',
#   'these',
#   'emissions',
#   'latest',
#   'annual',
#   'estimate',
#   'million',
#   'tonnes165',
#   'business',
#   'usual',
#   'basis',
#   'expected',
#   'annual',
#   'carbon',
#   'dioxide',
#   'emissions',
#   'will',
#   'actually',
#   'fall',
#   'million',
#   'tonnes',
#   '2025',
#   'per',
#   'cent',
#   'decrease',
#   '1990',
#   'levels',
#   '166',
#   'London',
#   'also',
#   'has',
#   'lowest',
#   'domestic',
#   'carbon',
#   'dioxide',
#   'emissions',
#   'per',
#   'person',
#   'per',
#   'year',
#   'tonnes',
#   'joint',
#   'lowest',
#   'transport',
#   'emission',
#   'rate',
#   'per',
#   'person',
#   'tonnes',
#   'all',
#   'regions167',
#   'This',
#   'largely',
#   'due',
#   'higher',
#   'use',
#   'public',
#   'transport',
#   'density',
#   'development',
#   'London',
#   'There',
#   'growing',
#   'scientific',
#   'consensus',
#   'stabilising',
#   'atmospheric',
#   'carbon',
#   'dioxide',
#   'emissions',
#   'levels',
#   'below',
#   '450',
#   'parts',
#   'per',
#   'million',
#   'required',
#   'avoid',
#   'catastrophic',
#   'strategic',
#   'target',
#   'Policy',
#   'represents',
#   'emissions',
#   'reduction',
#   'required',
#   'London',
#   'contribution',
#   'stabilising',
#   'world',
#   'emissions',
#   'this',
#   'level',
#   '2050',
#   'part',
#   'Act',
#   '2008',
#   'Government',
#   'established',
#   'target',
#   'reduce',
#   'greenhouse',
#   'gas',
#   'emissions',
#   'per',
#   'cent',
#   '2050',
#   'has',
#   'proposed',
#   'carbon',
#   'budgets',
#   'means',
#   'work',
#   'towards',
#   'this',
#   'target',
#   'strategic',
#   'target',
#   'Policy',
#   'will',
#   'extremely',
#   'challenging',
#   'but',
#   'will',
#   'achievable',
#   'full',
#   'commitment',
#   'collaboration',
#   'all',
#   'stakeholders',
#   'particularly',
#   'national',
#   'government',
#   'Progress',
#   'will',
#   'kept',
#   'under',
#   'review',
#   'ensure',
#   'policies',
#   'programmes',
#   'set',
#   'out',
#   'Mitigation',
#   'Energy',
#   'Strategy',
#   ...],
#  ['Localized',
#   'Projections',
#   'Waterloo',
#   'Region',
#   'September',
#   '2015',
#   'revised',
#   'Oct',
#   '2015',
#   'Prepared',
#   'Prepared',
#   'Cover',
#   'photos',
#   'Top',
#   'rooftop',
#   'Seagram',
#   'Lofts',
#   'provides',
#   'bird',
#   'eye',
#   'view',
#   'deadly',
#   'thunderstorm',
#   'rolling',
#   'over',
#   'Uptown',
#   'Waterloo',
#   'September',
#   '2014',
#   'Credit',
#   'Jason',
#   'Thistlethwaite',
#   'Bottom',
#   'left',
#   'Hail',
#   'Waterloo',
#   'Region',
#   'August',
#   '2015',
#   'Credit',
#   'Jason',
#   'Thistlethwaite',
#   'Bottom',
#   'right',
#   'Flash',
#   'flooding',
#   'Fairview',
#   'Park',
#   'Mall',
#   'Kitchener',
#   'June',
#   '2013',
#   'Credit',
#   'Driveseat',
#   'Kitchener',
#   'via',
#   'CTV',
#   'News',
#   'Kitchener',
#   'Contributors',
#   'Alex',
#   'Cadel',
#   'Candidate',
#   'Master',
#   'University',
#   'Waterloo',
#   'Sarah',
#   'Brown',
#   'Interdisciplinary',
#   'Centre',
#   'University',
#   'Waterloo',
#   'Chris',
#   'Fletcher',
#   'Department',
#   'Geography',
#   'University',
#   'Waterloo',
#   'Daniel',
#   'Scott',
#   'Department',
#   'Geography',
#   'University',
#   'Waterloo',
#   'Jason',
#   'Thistlethwaite',
#   'School',
#   'Environment',
#   'Enterprise',
#   'Development',
#   'University',
#   'Waterloo',
#   'Executive',
#   'Summary',
#   'Addressing',
#   'one',
#   'global',
#   'challenges',
#   'this',
#   'century',
#   'Regions',
#   'across',
#   'experiencing',
#   'changing',
#   'climatic',
#   'conditions',
#   'such',
#   'higher',
#   'average',
#   'temperatures',
#   'new',
#   'precipitation',
#   'patterns',
#   'increased',
#   'frequency',
#   'severity',
#   'extreme',
#   'weather',
#   'events',
#   'heat',
#   'waves',
#   'intense',
#   'rainfall',
#   'strong',
#   'winds',
#   'These',
#   'changes',
#   'having',
#   'variety',
#   'ecosystems',
#   'everyday',
#   'life',
#   'communities',
#   'including',
#   'property',
#   'damage',
#   'infrastructure',
#   'failure',
#   'during',
#   'extreme',
#   'events',
#   'shifting',
#   'growing',
#   'seasons',
#   'range',
#   'economic',
#   'losses',
#   'construction',
#   'delays',
#   'crop',
#   'damage',
#   'tourism',
#   'patterns',
#   'increased',
#   'health',
#   'risks',
#   'posed',
#   'extreme',
#   'weather',
#   'shifts',
#   'ranges',
#   'pests',
#   'infectious',
#   'disease',
#   'refers',
#   'measures',
#   'taken',
#   'reduce',
#   'vulnerability',
#   'natural',
#   'human',
#   'systems',
#   'actual',
#   'expected',
#   'effects',
#   'addition',
#   'efforts',
#   'mitigate',
#   'reducing',
#   'greenhouse',
#   'gas',
#   'GHG',
#   'emissions',
#   'importance',
#   'rising',
#   'across',
#   'Municipalities',
#   'being',
#   'called',
#   'upon',
#   'respond',
#   'vulnerabilities',
#   'exposed',
#   'current',
#   'changing',
#   'conditions',
#   'recent',
#   'extreme',
#   'weather',
#   'events',
#   'well',
#   'prepare',
#   'both',
#   'risks',
#   'opportunities',
#   'may',
#   'arise',
#   'given',
#   'longer',
#   '-\xad‐',
#   'term',
#   'local',
#   'City',
#   'Windsor',
#   'City',
#   'Toronto',
#   'example',
#   'have',
#   'developed',
#   'plans',
#   'were',
#   'driven',
#   'largely',
#   'response',
#   'extreme',
#   'heat',
#   'urban',
#   'flooding',
#   'pressures',
#   'affecting',
#   'their',
#   'respective',
#   'communities',
#   'enable',
#   'effective',
#   'planning',
#   'action',
#   'builds',
#   'community',
#   'resilience',
#   'imperative',
#   'municipal',
#   'decision',
#   '-\xad‐',
#   'makers',
#   'have',
#   'access',
#   'locally',
#   '-\xad‐',
#   'relevant',
#   'robust',
#   'projections',
#   'examine',
#   'how',
#   'temperature',
#   'precipitation',
#   'expected',
#   'future',
#   'effort',
#   'develop',
#   'localized',
#   'projections',
#   'Waterloo',
#   'Region',
#   'was',
#   'initiated',
#   'response',
#   'need',
#   'expressed',
#   'municipal',
#   'staff',
#   'gain',
#   'greater',
#   'understanding',
#   '-\xad‐',
#   'related',
#   'risks',
#   'relevant',
#   'our',
#   'region',
#   'means',
#   'inform',
#   'municipal',
#   'strategic',
#   'collaborative',
#   'planning',
#   'University',
#   'Waterloo',
#   'Interdisciplinary',
#   'Centre',
#   'IC3',
#   'prepared',
#   'this',
#   'report',
#   'contribute',
#   'ongoing',
#   'collaborations',
#   'action',
#   'between',
#   'Cities',
#   'Cambridge',
#   'Kitchener',
#   'Waterloo',
#   'Region',
#   'Waterloo',
#   'purpose',
#   'report',
#   'summarize',
#   'information',
#   'projected',
#   'our',
#   'local',
#   'region',
#   'could',
#   'aid',
#   'advancing',
#   'local',
#   'dialogue',
#   'planning',
#   'extreme',
#   'weather',
#   'resilience',
#   'How',
#   'localized',
#   'projections',
#   'developed',
#   'process',
#   'developing',
#   'projections',
#   'uses',
#   'both',
#   'historical',
#   'weather',
#   'data',
#   'this',
#   'region',
#   'well',
#   'ensemble',
#   'models',
#   'which',
#   'provide',
#   'best',
#   'available',
#   'scientific',
#   'assessment',
#   'how',
#   'future',
#   'social',
#   'economic',
#   'conditions',
#   'will',
#   'influence',
#   'global',
#   'system',
#   'this',
#   'region',
#   'Warren',
#   'Lemmen',
#   'editors',
#   '2014',
#   'Changing',
#   'Sector',
#   'Perspectives',
#   'Government',
#   'Ottawa',
#   '286p',
#   'Waterloo',
#   'Region',
#   'projections',
#   'number',
#   'parameters',
#   'interest',
#   'municipal',
#   'stakeholders',
#   'monthly',
#   'mean',
#   'temperature',
#   'seasonal',
#   'precipitation',
#   'have',
#   'been',
#   'provided',
#   'three',
#   'different',
#   'time',
#   'periods',
#   '2020s',
#   '2050s',
#   '2080s',
#   'respectively',
#   'covering',
#   'years',
#   '2011',
#   '-\xad‐',
#   '2040',
#   '2041',
#   '2070',
#   '2071',
#   '-\xad‐',
#   '2100',
#   'projected',
#   'changes',
#   'relative',
#   'historical',
#   'data',
#   '1990s',
#   '1981',
#   '-\xad‐',
#   '2010',
#   'baseline',
#   'observed',
#   'period',
#   'Across',
#   'each',
#   'these',
#   'time',
#   'periods',
#   'three',
#   'different',
#   'future',
#   'GHG',
#   'emissions',
#   'scenarios',
#   'examined',
#   'net',
#   '-\xad‐',
#   'zero',
#   'carbon',
#   'emission',
#   'scenario',
#   'would',
#   'necessary',
#   'limit',
#   'global',
#   'warming',
#   '2oC',
#   'aggressive',
#   'emission',
#   'reduction',
#   'scenario',
#   'consistent',
#   'emission',
#   'reduction',
#   'pledges',
#   'countries',
#   'business',
#   '-\xad‐',
#   '-\xad‐',
#   'usual',
#   'BAU',
#   'emission',
#   'trajectory',
#   'Our',
#   'current',
#   'trajectory',
#   'global',
#   'society',
#   'line',
#   'BAU',
#   'scenario',
#   'recent',
#   'global',
#   'efforts',
#   'curb',
#   'GHG',
#   'emissions',
#   'have',
#   'not',
#   'yet',
#   'been',
#   'substantial',
#   'enough',
#   'deviate',
#   'this',
#   'path',
#   'other',
#   'two',
#   'scenarios',
#   'considered',
#   'here',
#   'still',
#   'plausible',
#   'however',
#   'substantial',
#   'international',
#   'commitment',
#   'will',
#   'required',
#   'reduce',
#   'emissions',
#   'levels',
#   'which',
#   'those',
#   'scenarios',
#   'based',
#   'Which',
#   'conditions',
#   'projected',
#   'Waterloo',
#   'Region',
#   'how',
#   'much',
#   'when',
#   'Temperature',
#   'Annual',
#   'mean',
#   'temperature',
#   'projected',
#   'increase',
#   'about',
#   '-\xad‐',
#   '3oC',
#   '2050s',
#   'across',
#   'all',
#   'emission',
#   'scenarios',
#   'Increases',
#   'monthly',
#   'temperatures',
#   'projected',
#   'most',
#   'marked',
#   'throughout',
#   'winter',
#   'into',
#   'early',
#   'summer',
#   'see',
#   'Table',
#   'ES1',
#   'example',
#   'under',
#   'all',
#   'scenarios',
#   'monthly',
#   'mean',
#   'temperature',
#   'February',
#   '2050s',
#   'expected',
#   '-\xad‐',
#   '5oC',
#   'warmer',
#   'than',
#   'today',
#   'pushing',
#   'average',
#   'temperature',
#   'month',
#   'closer',
#   'slightly',
#   'above',
#   '0oC',
#   'Currently',
#   'region',
#   'experiences',
#   'around',
#   'days',
#   'per',
#   'year',
#   'extreme',
#   'heat',
#   'daily',
#   'maximum',
#   'temperature',
#   'exceeding',
#   '30oC',
#   'Under',
#   'BAU',
#   'scenario',
#   'number',
#   'days',
#   'extreme',
#   'heat',
#   'projected',
#   'more',
#   'than',
#   'triple',
#   'days',
#   '2050s',
#   'then',
#   'nearly',
#   'double',
#   'again',
#   'days',
#   '2080s',
#   'see',
#   'Figure',
#   'ES1',
#   'Currently',
#   'around',
#   'days',
#   'per',
#   'year',
#   'observed',
#   'extremely',
#   'cold',
#   'temperatures',
#   'daily',
#   'minimum',
#   'temperature',
#   'lower',
#   'than',
#   '-\xad‐',
#   '15oC',
#   'reduction',
#   'number',
#   'extremely',
#   'cold',
#   'days',
#   'projected',
#   'under',
#   'all',
#   'scenarios',
#   'less',
#   'than',
#   'half',
#   'many',
#   'extreme',
#   'cold',
#   'days',
#   'occurring',
#   '2020s',
#   'were',
#   'recorded',
#   'during',
#   '1990s',
#   'further',
#   'reductions',
#   'occurring',
#   'over',
#   'rest',
#   'century',
#   'few',
#   'days',
#   '2080s',
#   'under',
#   'BAU',
#   'scenario',
#   'iii',
#   'Table',
#   'ES1',
#   'Range',
#   'projected',
#   'changes',
#   'Waterloo',
#   'Region',
#   '2050s',
#   'compared',
#   '1990s',
#   'Temperature',
#   'Precipitation',
#   '(%)',
#   'Scenario',
#   'Summer',
#   'Winter',
#   'Summer',
#   'Winter',
#   'Net',
#   '-\xad‐',
#   'zero',
#   'carbon',
#   '-\xad‐',
#   'Aggressive',
#   'mitigation',
#   '-\xad‐',
#   'Business',
#   '-\xad‐',
#   '-\xad‐',
#   'usual',
#   'Figure',
#   'ES1',
#   'demonstrates',
#   'average',
#   'annual',
#   'number',
#   'days',
#   'projected',
#   'reach',
#   'extreme',
#   'heat',
#   'conditions',
#   'which',
#   'defined',
#   'days',
#   'where',
#   'maximum',
#   'air',
#   'temperatures',
#   'reach',
#   'exceed',
#   '30oC',
#   'These',
#   'values',
#   'shown',
#   'comparison',
#   'observed',
#   'average',
#   'value',
#   'days',
#   '1990s',
#   'period',
#   'Error',
#   'bars',
#   'represent',
#   'range',
#   'uncertainty',
#   'multi',
#   '-\xad‐',
#   'model',
#   'ensemble',
#   'Precipitation',
#   'Total',
#   'annual',
#   'precipitation',
#   'projected',
#   'increase',
#   'approximately',
#   '-\xad‐',
#   '2020s',
#   'approximately',
#   '-\xad‐',
#   '2050s',
#   '2080s',
#   'see',
#   'Table',
#   'ES1',
#   'Seasonally',
#   'largest',
#   'precipitation',
#   'increases',
#   'expected',
#   'winter',
#   'spring',
#   'summer',
#   'although',
#   'magnitude',
#   'summer',
#   'associated',
#   'largest',
#   'range',
#   'uncertainty',
#   'due',
#   'lack',
#   'consensus',
#   'between',
#   'models',
#   '2020s',
#   '2050s',
#   '2080s',
#   'Time',
#   'period',
#   '-\xad‐',
#   'year',
#   'averages',
#   'Figure',
#   'ES1',
#   'Extreme',
#   'heat',
#   'Waterloo',
#   'Region',
#   'Net',
#   '-\xad‐',
#   'zero',
#   'carbon',
#   'Aggressive',
#   'miigaion',
#   'Business',
#   '-\xad‐',
#   '-\xad‐',
#   'usual',
#   'Observed',
#   '1990s',
#   'Increased',
#   'amounts',
#   'precipitation',
#   'likely',
#   'initially',
#   'result',
#   'increases',
#   'total',
#   'annual',
#   'snow',
#   '2020s',
#   'yet',
#   'into',
#   '2050s',
#   '2080s',
#   'warmer',
#   'winter',
#   'temperatures',
#   'likely',
#   'cause',
#   'less',
#   'precipitation',
#   'fall',
#   'form',
#   'snow',
#   'compared',
#   'today',
#   'Southern',
#   'Ontario',
#   'months',
#   'December',
#   'January',
#   'February',
#   'expected',
#   'experience',
#   'more',
#   'freezing',
#   'rain',
#   'events',
#   '2050s',
#   'more',
#   'freezing',
#   'rain',
#   'events',
#   '2080s',
#   'Rainfall',
#   'intensities',
#   'projected',
#   'increase',
#   'across',
#   'all',
#   'scenarios',
#   'time',
#   'periods',
#   'large',
#   '-\xad‐',
#   'magnitude',
#   'rainfall',
#   'events',
#   'expected',
#   'occur',
#   'more',
#   'frequently',
#   'than',
#   'historical',
#   'record',
#   'variability',
#   'precipitation',
#   'events',
#   'does',
#   'not',
#   'then',
#   'projected',
#   'slightly',
#   'decrease',
#   'frequency',
#   '-\xad‐',
#   'day',
#   'dry',
#   'spells',
#   'average',
#   'events',
#   'occurring',
#   'per',
#   'year',
#   '2050s',
#   'Wind',
#   'More',
#   'wind',
#   'gust',
#   'events',
#   'expected',
#   'Southern',
#   'Ontario',
#   'end',
#   'century',
#   'both',
#   'large',
#   '-\xad‐',
#   'scale',
#   'frontal',
#   'storms',
#   'local',
#   'convective',
#   'windstorms',
#   'projected',
#   'occur',
#   'more',
#   'frequently',
#   'What',
#   'action',
#   'can',
#   'taken',
#   'municipal',
#   'level',
#   'respond',
#   'these',
#   'projected',
#   'changes',
#   'Successful',
#   'requires',
#   'robust',
#   'range',
#   'projections',
#   'how',
#   'local',
#   'expected',
#   'evolve',
#   'well',
#   'understanding',
#   'remaining',
#   'scientific',
#   'uncertainties',
#   'Projections',
#   'can',
#   'considered',
#   'starting',
#   'point',
#   'towards',
#   'developing',
#   'shared',
#   'base',
#   'information',
#   'upon',
#   'which',
#   'develop',
#   'plan',
#   'specific',
#   'responses',
#   'projects',
#   'Having',
#   'access',
#   'future',
#   'scenarios',
#   'what',
#   'expected',
#   'look',
#   'like',
#   'Waterloo',
#   'Region',
#   'one',
#   'foundational',
#   'steps',
#   'planning',
#   'process',
#   'along',
#   'identifying',
#   'stakeholders',
#   'assessing',
#   'current',
#   'both',
#   'risks',
#   'opportunities',
#   'Using',
#   'localized',
#   'projections',
#   'other',
#   'community',
#   'knowledge',
#   'inputs',
#   'full',
#   'assessment',
#   'potential',
#   'vulnerability',
#   'across',
#   'community',
#   'assets',
#   'services',
#   'can',
#   'begin',
#   'Contents',
#   'Executive',
#   'Summary',
#   '......................................................................................................................................',
#   'List',
#   'Figures',
#   '...............................................................................................................................................',
#   'List',
#   'Tables',
#   '................................................................................................................................................',
#   'Introduction',
#   '........................................................................................................................................',
#   'Report',
#   'purpose',
#   'context',
#   '..............................................................................................................',
#   'Study',
#   'area',
#   '..........................................................................................................................................',
#   'What',
#   'difference',
#   'between',
#   'weather',
#   '....................................................................',
#   'Overview',
#   'modelling',
#   'process',
#   '.....................................................................................................',
#   'Why',
#   'use',
#   'modelling',
#   '..............................................................................................................',
#   'What',
#   'statistical',
#   'downscaling',
#   '........................................................................................................',
#   ...]]

# %%
# check how many documents are being used
len(docs)
# Out:
# 56

# %%
# define a normalizer class
class TextNormalizer(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.lemmatizer = WordNetLemmatizer()
    
    # define function for punctuation marks
    def is_punct(self, token):
        return all(unicodedata.category(char).startswith('P') for char in token)
    
    def normalize(self, document):
        return [
            # here you could return a lemmatized token instead
            token.lower()
            for sentence in document
            for token in sentence
            # check if a punctuation mark
            if not self.is_punct(token)
        ]
    
    # create a lemmatizer function
    def lemmatize(self, token):
        return self.lemmatizer.lemmatize(token)
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, documents):
        return [''.join(self.normalize(doc)) for doc in documents]

# %%
# initialize normalizer class
norm = TextNormalizer()

# %%
# create a list of the normalized documents
docs_normalized = []
# iterate through each document and apply the normalizer
for i in docs:
    docs_normalized.append(norm.fit_transform(i))

# take a look at the normalized documents
print(docs_normalized)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# create a dictionary of the documents.
dictionary = Dictionary(docs_normalized)

# filter out words present in less than 3 documents or in more than 90% of the documents.
dictionary.filter_extremes(no_below=3, no_above=0.9)
# Out:
# 2019-12-15 02:03:40,544 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2019-12-15 02:03:41,245 : INFO : built Dictionary(35146 unique tokens: ['', '000', '07023', '100', '10027']...) from 56 documents (total 950187 corpus positions)
# 2019-12-15 02:03:41,303 : INFO : discarding 24181 tokens: [('07023', 1), ('2016e', 2), ('27086', 1), ('2mw', 1), ('3154', 2), ('315climateenglishreducedsize10', 1), ('36283', 1), ('50001', 2), ('523', 2), ('558', 1)]...
# 2019-12-15 02:03:41,304 : INFO : keeping 10965 tokens which were in no less than 3 and no more than 50 (=90.0%) documents
# 2019-12-15 02:03:41,331 : INFO : resulting dictionary: Dictionary(10965 unique tokens: ['', '000', '100', '10027', '110']...)

# %%
# create a bow representation of the documents.
corpus = [dictionary.doc2bow(doc) for doc in docs_normalized]

# %%
# check the number of tokens and the number of documents
print('Number of unique tokens: %d' % len(dictionary))
print('Number of documents: %d' % len(corpus))
# Out:
# Number of unique tokens: 10965
# Number of documents: 56

# %%
# index word dictionary
temp = dictionary[0]  
id2word = dictionary.id2token
# create the model
model = LdaModel(
    corpus=corpus,
    id2word=id2word,
    alpha='auto',
    eta='auto',
    num_topics=3,
    eval_every=1,
    random_state=42
)
# Out:
# 2019-12-15 02:03:41,711 : INFO : using autotuned alpha, starting with [0.33333334, 0.33333334, 0.33333334]
# 2019-12-15 02:03:41,717 : INFO : using serial LDA version on this node
# 2019-12-15 02:03:41,733 : INFO : running online (single-pass) LDA training, 3 topics, 1 passes over the supplied corpus of 56 documents, updating model once every 56 documents, evaluating perplexity every 56 documents, iterating 50x with a convergence threshold of 0.001000
# 2019-12-15 02:03:41,734 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2019-12-15 02:03:42,502 : INFO : -9.742 per-word bound, 856.6 perplexity estimate based on a held-out corpus of 56 documents with 786045 words
# 2019-12-15 02:03:42,503 : INFO : PROGRESS: pass 0, at document #56/56
# 2019-12-15 02:03:42,702 : INFO : optimized alpha [0.6154381, 0.6088842, 0.5863802]
# 2019-12-15 02:03:42,707 : INFO : topic #0 (0.615): 0.005*"emissions" + 0.004*"development" + 0.004*"energy" + 0.004*"changes" + 0.004*"management" + 0.004*"future" + 0.004*"risks" + 0.004*"report" + 0.003*"infrastructure" + 0.003*"transportation"
# 2019-12-15 02:03:42,709 : INFO : topic #1 (0.609): 0.004*"energy" + 0.004*"sea" + 0.004*"local" + 0.004*"changes" + 0.004*"land" + 0.004*"report" + 0.004*"research" + 0.003*"emissions" + 0.003*"government" + 0.003*"future"
# 2019-12-15 02:03:42,711 : INFO : topic #2 (0.586): 0.005*"sea" + 0.004*"report" + 0.004*"energy" + 0.004*"flood" + 0.003*"management" + 0.003*"coastal" + 0.003*"land" + 0.003*"development" + 0.003*"transportation" + 0.003*"changes"
# 2019-12-15 02:03:42,712 : INFO : topic diff=1.480965, rho=1.000000

# %%
# find the top 10 words for each topic
top_topics = model.top_topics(corpus, topn=10)

# %%
# print the top 3 topics, and the top 10 words within those topics
# also includes the topics coherence scores
pprint(top_topics)
# Out:
# [([(0.004416227, 'energy'),
#    (0.004301955, 'sea'),
#    (0.0041628396, 'local'),
#    (0.0039565014, 'changes'),
#    (0.003833714, 'land'),
#    (0.0036392733, 'report'),
#    (0.0035467532, 'research'),
#    (0.0034543115, 'emissions'),
#    (0.003360343, 'government'),
#    (0.0031983773, 'future')],
#   -0.08435206985256147),
#  ([(0.00451812, 'emissions'),
#    (0.0044105616, 'development'),
#    (0.004219287, 'energy'),
#    (0.0040020016, 'changes'),
#    (0.0038823118, 'management'),
#    (0.0037134914, 'future'),
#    (0.0036080242, 'risks'),
#    (0.003539546, 'report'),
#    (0.0033220325, 'infrastructure'),
#    (0.0030308308, 'transportation')],
#   -0.09376667704954592),
#  ([(0.0050185476, 'sea'),
#    (0.004231277, 'report'),
#    (0.0041005397, 'energy'),
#    (0.0036841661, 'flood'),
#    (0.0034437878, 'management'),
#    (0.0033724422, 'coastal'),
#    (0.0032880555, 'land'),
#    (0.0032516045, 'development'),
#    (0.0032026565, 'transportation'),
#    (0.0030936964, 'changes')],
#   -0.11112625537166283)]

# %%
# prepare inputs for the visualization
tfidf_model = TfidfModel(corpus)
corpus_tfidf = tfidf_model[corpus]
# Out:
# 2019-12-15 02:03:42,781 : INFO : collecting document frequencies
# 2019-12-15 02:03:42,784 : INFO : PROGRESS: processing document #0
# 2019-12-15 02:03:42,820 : INFO : calculating IDF weights for 56 documents and 10965 features (121906 matrix non-zeros)

# %%
# initialize the visualization
viz = pyLDAvis.gensim.prepare(model, corpus_tfidf, dictionary)
# display the visualization
pyLDAvis.display(viz)
# Out:
# 2019-12-15 02:03:44,724 : INFO : NumExpr defaulting to 4 threads.
# /opt/anaconda3/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el297001124680192801996425384"></div>
# <script type="text/javascript">
#
# var ldavis_el297001124680192801996425384_data = {"mdsDat": {"x": [0.0036988806832300774, -0.0050538678620165355, 0.0013549871787864618], "y": [-0.003243308390621605, -0.001186166549451708, 0.004429474940073313], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [37.3427734375, 33.08232498168945, 29.574901580810547]}, "tinfo": {"Category": ["Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Default", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic1", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic2", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3", "Topic3"], "Freq": [4.0, 2.0, 3.0, 1.0, 3.0, 2.0, 3.0, 3.0, 1.0, 3.0, 3.0, 1.0, 3.0, 2.0, 4.0, 0.0, 2.0, 0.0, 2.0, 4.0, 2.0, 0.0, 0.0, 1.0, 2.0, 1.0, 0.0, 2.0, 1.0, 0.0, 0.027107881382107735, 0.02127435989677906, 0.04706417769193649, 0.006524679716676474, 0.03887118771672249, 0.03913607448339462, 0.007910835556685925, 0.016427073627710342, 0.02038649655878544, 0.06463982164859772, 0.0033460105769336224, 0.028216993436217308, 0.004172708373516798, 0.00410840567201376, 0.010753094218671322, 0.005749797914177179, 0.09483855217695236, 0.12257025390863419, 0.004081417340785265, 0.005689218174666166, 0.003268830943852663, 0.013792022131383419, 0.024291405454277992, 0.0252352 ...

# %%
# save the visualization.
pyLDAvis.save_html(viz, 'gensim_climate_change_lda_model.html')

# %%
# read a new file not trained to the model
new_doc = PlaintextCorpusReader(root='/Users/rahimjiwa/Documents/DataScience/UofT3666_AppliedNLP/Final_Testings',fileids='random_pdf.txt')
# get a list of words
new_doc = list(new_doc.words())
# create a bow representations of the new documents
new_doc_bow = dictionary.doc2bow(new_doc)
# get the document distributions
print(model.get_document_topics(new_doc_bow))
# Out:
# [(0, 0.24605206), (1, 0.12830782), (2, 0.62564015)]

# %%
# get the coherence score
coherence_model = CoherenceModel(model=model, corpus=corpus, coherence='u_mass')
print("Coherence: " + str(coherence_model.get_coherence()))
# Out:
# Coherence: -0.15028962290524578

# %%
# get the perplexity score
print("Perplexity: " + str(model.log_perplexity(corpus)))
# Out:
# 2019-12-15 02:10:32,203 : INFO : -8.036 per-word bound, 262.5 perplexity estimate based on a held-out corpus of 56 documents with 786045 words
# Perplexity: -8.03618820716205
