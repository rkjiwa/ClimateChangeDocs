# %% [markdown]
# #Project_Draft_J_Parse_Classifier
#
# This notebook implements a classification model on syntactic parse trees to identify actions.

# %% [markdown]
# ##Set up Drive

# %%
#authorize Colab to access Drive
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %% [markdown]
# ##Imports

# %%
import csv
import os

import tabulate
import numpy as np

from collections import defaultdict

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.decomposition import TruncatedSVD
#from sklearn.ensemble import RandomForestClassifier
#from sklearn.naive_bayes import MultinomialNB

import gensim
from gensim.corpora import Dictionary
from gensim.models import TfidfModel
from gensim.matutils import sparse2full

# %% [markdown]
# ## Define Vectorizer Class

# %%
class GensimTfidfVectorizer(BaseEstimator, TransformerMixin):

    def __init__(self, dirpath=".", tofull=False):
        """
        Pass in a directory that holds the lexicon in corpus.dict and the
        TFIDF model in tfidf.model (for now).

        Set tofull = True if the next thing is a Scikit-Learn estimator
        otherwise keep False if the next thing is a Gensim model.
        """
        self._lexicon_path = os.path.join(dirpath, "corpus.dict")
        self._tfidf_path = os.path.join(dirpath, "tfidf.model")

        self.lexicon = None
        self.tfidf = None
        self.tofull = tofull

        self.load()

    def load(self):

        if os.path.exists(self._lexicon_path):
            self.lexicon = Dictionary.load(self._lexicon_path)

        if os.path.exists(self._tfidf_path):
            self.tfidf = TfidfModel().load(self._tfidf_path)

    def save(self):
        self.lexicon.save(self._lexicon_path)
        self.tfidf.save(self._tfidf_path)

    def fit(self, documents, labels=None):
        self.lexicon = Dictionary(documents)
        self.tfidf = TfidfModel([self.lexicon.doc2bow(doc) for doc in documents], id2word=self.lexicon)
        self.save()
        return self

    def transform(self, documents):
        def generator():
            for document in documents:
                vec = self.tfidf[self.lexicon.doc2bow(document)]
                if self.tofull:
                    yield sparse2full(vec, len(self.lexicon))
                else:
                    yield vec
        return list(generator())

# %% [markdown]
# ## Define CorpusLoader Class to manage the folds for cross-validation

# %%
import numpy as np
from sklearn.model_selection import KFold

class CorpusLoader(object):
    """
    Splits a list of vectors and their labels
    """
    def __init__(self, vectors, labels, splits=12):
        self.folds = KFold(n_splits=splits, shuffle=True)
        self.X = np.asarray(vectors)
        self.y = np.asarray(labels)

    def documents(self, idx=None):
        #temp = [doc for doc in self.X[idx]]
        #print('docs: ', temp)
        #return(temp)
        return [doc for doc in self.X[idx]]

    def labels(self, idx):
        return self.y[idx]

    def __iter__(self):
        for train_index, test_index in self.folds.split(self.X):
            X_train = self.documents(train_index)
            y_train = self.labels(train_index)

            X_test = self.documents(test_index)
            y_test = self.labels(test_index)

            yield X_train, X_test, y_train, y_test

# %% [markdown]
# ## Define Create_Pipeline Function
#
# not currently in use

# %%
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import Pipeline

def create_pipeline(estimator, reduction=False):

    steps = []
    steps.append(('vectorization', GensimTfidfVectorizer(".", True)))

    # Apply Truncated SVD if requested
    if reduction:
        steps.append((
            'reduction', TruncatedSVD(n_components=50)
        ))

    # Add the estimator
    steps.append(('classifier', estimator))
    
    # Actual Pipeline object is created here
    return Pipeline(steps)

# %% [markdown]
# ##Main section

# %% [markdown]
# ### Read in the Pickled Parses and Labels
#
# Non-actions are duplicated to approximate the same number as the Actions, so the training data is balanced.

# %%
# These functions are provided for normalization, but may not be needed. 
# The tf-idf vectorization may automatically take care of de-emphasizing sentence-final punctuation.

# is-punct function recognizes punctuation 
def is_punct(token):
    return token.startswith(('LEFT_punct_', 'RIGHT_punct_'))

# Normalizer function strips off right hand punctuation, since this occurs in almost every sentence
def normalize(sentence):
    if is_punct(sentence[-1]):
        return sentence[:-1]

    else:    
        return sentence

# %%
# location of pickle files
actions_file = '/gdrive/My Drive/Colab Notebooks/3666 ANLP/Project/Climate Change Docs - Actions.pkl'
non_actions_file = '/gdrive/My Drive/Colab Notebooks/3666 ANLP/Project/Climate Change Docs - Non-Actions.pkl'

#initialize accumulators
corpus = []
labels = []

with open(actions_file, 'r', encoding="utf8", errors='ignore') as f:
    reader = csv.reader(f, delimiter=' ')
    for row in reader:
#        corpus.append(normalize(row)) ## normalization may not be needed
        corpus.append(row)
        labels.append('action')

with open(non_actions_file, 'r', encoding="utf8", errors='ignore') as f:
    reader = csv.reader(f, delimiter=' ')
    for row in reader:
#        row = normalize(row)
        corpus.append(row)
        corpus.append(row)
        labels.append('non_action')
        labels.append('non_action')

# %%
for i in range(len(corpus)):
  print(labels[i], corpus[i])
# Out:
# action ['ROOT_self_VB', 'LEFT_aux_VB', 'LEFT_nsubj_NN', 'RIGHT_dobj_NN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_neg_RB', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_punct_,', 'LEFT_advcl_VBN', 'LEFT_punct_,', 'LEFT_aux_TO', 'RIGHT_dobj_NNS', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_,', 'RIGHT_advcl_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_JJ', 'LEFT_punct_,', 'RIGHT_dobj_NNS', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prep_IN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_csubj_VB', 'LEFT_aux_VBP', 'LEFT_neg_RB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_NNS', 'LEFT_amod_JJ', 'RIGHT_cc_CC', 'RIGHT_conj_NN', 'RIGHT_prep_IN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_NN', 'LEFT_prep_IN', 'LEFT_punct_,', 'LEFT_dep_NN', 'LEFT_nummod_CD', 'RIGHT_punct_-RRB-', 'RIGHT_advmod_RB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBN', 'RIGHT_dobj_NN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_ADD', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_ADD', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBP', 'LEFT_advmod_RB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_JJ', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_,', 'RIGHT_advcl_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_prt_RB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_aux_VB', 'LEFT_neg_RB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_ccomp_VBZ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_,', 'RIGHT_conj_NN', 'RIGHT_advcl_VBP', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_ccomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBP', 'LEFT_punct_,', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_ccomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_ccomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VB', 'LEFT_punct_,', 'LEFT_nsubj_PRP', 'LEFT_aux_MD', 'RIGHT_xcomp_VB']
# action ['ROOT_self_VB', 'LEFT_advmod_RB', 'RIGHT_ccomp_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VB']
# action ['ROOT_self_VB', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_intj_UH', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN']
# action ['ROOT_self_VB', 'RIGHT_prep_IN', 'RIGHT_advcl_VB', 'RIGHT_punct_,', 'RIGHT_advcl_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VB', 'LEFT_punct_,', 'LEFT_nsubj_PRP', 'LEFT_aux_MD', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN']
# action ['ROOT_self_VB', 'LEFT_advcl_VBD', 'LEFT_punct_,', 'RIGHT_dobj_PRP', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_prep_IN']
# action ['ROOT_self_VB', 'LEFT_prep_IN', 'LEFT_punct_,', 'RIGHT_dobj_ADD', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_,', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_:']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_ccomp_VBN']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_advcl_VB']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_PRP', 'LEFT_aux_MD', 'LEFT_advmod_RB', 'RIGHT_dobj_NNP', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_NNS', 'LEFT_amod_JJ', 'RIGHT_punct_,', 'RIGHT_conj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_NN', 'LEFT_compound_VB', 'RIGHT_punct_,', 'RIGHT_conj_NNS', 'RIGHT_prep_IN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VB', 'LEFT_punct_,', 'RIGHT_dobj_PRP', 'RIGHT_prt_RP', 'RIGHT_cc_CC', 'RIGHT_conj_VB']
# action ['ROOT_self_VBG', 'LEFT_csubj_VB', 'LEFT_aux_VBP', 'RIGHT_advmod_RB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBZ', 'RIGHT_ccomp_VBP']
# action ['ROOT_self_VB', 'RIGHT_ccomp_VBP', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_ccomp_VBN', 'RIGHT_ccomp_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advmod_RB', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_PRP', 'RIGHT_punct_,', 'RIGHT_npadvmod_NNS', 'RIGHT_cc_CC', 'RIGHT_conj_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_advcl_VBP', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_aux_VB', 'LEFT_neg_RB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_PRP', 'RIGHT_punct_,', 'RIGHT_npadvmod_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_aux_VB', 'LEFT_neg_RB', 'RIGHT_dobj_NN', 'RIGHT_advcl_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_prep_IN', 'LEFT_punct_,', 'LEFT_nsubj_PRP', 'LEFT_aux_MD', 'RIGHT_ccomp_VBZ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBP', 'LEFT_punct_,', 'RIGHT_dobj_NNS', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advmod_RB', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VB', 'LEFT_punct_:', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_dobj_PRP', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN']
# action ['ROOT_self_VB', 'LEFT_advcl_VBZ', 'LEFT_punct_,', 'RIGHT_prt_RP', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_RB', 'LEFT_punct_,', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VB']
# action ['ROOT_self_VB', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_advcl_VBP', 'RIGHT_punct_-LRB-', 'RIGHT_advcl_VBP', 'RIGHT_punct_-RRB-', 'RIGHT_advcl_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBN', 'LEFT_punct_,', 'RIGHT_prep_IN']
# action ['ROOT_self_VB', 'LEFT_advcl_VBN', 'LEFT_punct_,', 'RIGHT_prep_IN']
# action ['ROOT_self_VB', 'LEFT_advcl_VBG', 'RIGHT_prep_IN', 'RIGHT_punct_,', 'RIGHT_advcl_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prt_RP', 'RIGHT_prep_IN']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_ccomp_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_acomp_JJ', 'RIGHT_advcl_VBN']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_cc_CC', 'RIGHT_conj_NNS', 'RIGHT_cc_CC', 'RIGHT_conj_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_prep_IN', 'LEFT_punct_,', 'RIGHT_prep_IN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBP', 'LEFT_punct_,', 'RIGHT_dobj_NN', 'RIGHT_advcl_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBP', 'LEFT_punct_,', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_PRP', 'RIGHT_punct_,', 'RIGHT_npadvmod_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_aux_VB', 'LEFT_neg_RB', 'RIGHT_dobj_NN', 'RIGHT_advcl_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBZ', 'LEFT_punct_,', 'RIGHT_prt_RP', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_advmod_RB']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prep_RP', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_JJ', 'LEFT_punct_,', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_JJ', 'LEFT_punct_,', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBD', 'LEFT_punct_,', 'RIGHT_acomp_VBN']
# action ['ROOT_self_VB', 'LEFT_nsubj_PRP', 'LEFT_aux_MD', 'LEFT_advmod_RB', 'RIGHT_dobj_NNP', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_PRP', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_advcl_VBZ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_aux_VB', 'LEFT_neg_RB', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_advmod_RB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_ccomp_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_cc_CC', 'RIGHT_conj_NNS', 'RIGHT_cc_CC', 'RIGHT_conj_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VB', 'RIGHT_prep_IN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prep_IN', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_ccomp_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBP', 'LEFT_punct_,', 'LEFT_aux_VB', 'LEFT_neg_RB', 'RIGHT_advmod_RB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_aux_VB', 'LEFT_neg_RB', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN']
# action ['ROOT_self_VB', 'LEFT_advcl_VBZ', 'LEFT_punct_,', 'RIGHT_prt_RP', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_advcl_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_MD', 'LEFT_neg_RB', 'LEFT_punct_,', 'LEFT_aux_VB', 'LEFT_neg_RB', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_aux_VB', 'LEFT_neg_RB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_aux_VB', 'LEFT_neg_RB', 'RIGHT_dobj_NN', 'RIGHT_xcomp_VBG']
# action ['ROOT_self_VB', 'LEFT_csubj_VBG', 'LEFT_aux_MD', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_punct_:']
# action ['ROOT_self_VB', 'LEFT_prep_VBG', 'LEFT_punct_,', 'LEFT_nsubj_PRP', 'LEFT_aux_MD', 'RIGHT_xcomp_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_xcomp_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBP', 'LEFT_punct_,', 'RIGHT_dobj_NN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_advmod_RB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'LEFT_neg_RB', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubj_VB', 'RIGHT_cc_CC', 'RIGHT_conj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_RB', 'RIGHT_cc_CC', 'RIGHT_conj_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_csubj_VBG', 'LEFT_aux_MD', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VBG', 'LEFT_nsubj_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_xcomp_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_advcl_VBP', 'LEFT_punct_,', 'LEFT_nsubjpass_PRP', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NN', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_punct_.']
# action ['ROOT_self_NNS', 'LEFT_compound_NN', 'RIGHT_punct_,', 'RIGHT_conj_NNS', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_NNS', 'LEFT_amod_JJ', 'RIGHT_relcl_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_advcl_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_prep_IN', 'LEFT_punct_,', 'RIGHT_dobj_NN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_NNS', 'LEFT_compound_NN', 'RIGHT_prep_IN', 'RIGHT_advcl_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_oprd_JJ', 'RIGHT_cc_CC', 'RIGHT_conj_VBN', 'RIGHT_punct_:']
# action ['ROOT_self_JJ', 'LEFT_advmod_RB', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_punct_,', 'RIGHT_conj_VBG', 'RIGHT_relcl_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_xcomp_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_NN', 'RIGHT_dobj_NNS', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_xcomp_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prt_RP', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prt_RP', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_mark_IN', 'LEFT_prep_IN', 'LEFT_punct_,', 'RIGHT_dobj_PRP', 'RIGHT_prt_RP', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_aux_VB', 'LEFT_neg_RB', 'RIGHT_dobj_NNS', 'RIGHT_advmod_RB', 'RIGHT_punct_.']
# action ['ROOT_self_NNP', 'LEFT_compound_NNP', 'LEFT_compound_NNP', 'RIGHT_prep_IN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advmod_RB', 'RIGHT_dobj_NNS', 'RIGHT_prep_IN', 'RIGHT_punct_,', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNP', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_NN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_NNS', 'LEFT_compound_JJ', 'RIGHT_relcl_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_VBG', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_NN', 'LEFT_compound_NN', 'RIGHT_prep_IN', 'RIGHT_prep_IN']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NN', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_prep_IN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_aux_VB', 'LEFT_neg_RB', 'RIGHT_dobj_NNS', 'RIGHT_advcl_VBP', 'RIGHT_punct_.']
# action ['ROOT_self_VBZ', 'LEFT_advcl_VBP', 'LEFT_punct_,', 'LEFT_nsubj_PRP', 'RIGHT_acomp_JJ', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBG', 'LEFT_punct_,', 'LEFT_intj_UH', 'RIGHT_ccomp_VBP', 'RIGHT_punct_.']
# action ['ROOT_self_NNP', 'LEFT_compound_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBG', 'LEFT_punct_,', 'LEFT_intj_UH', 'RIGHT_ccomp_VBP', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBG', 'LEFT_punct_,', 'LEFT_intj_UH', 'RIGHT_ccomp_VBP', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_xcomp_VBG', 'RIGHT_punct_,', 'RIGHT_npadvmod_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBG', 'LEFT_punct_,', 'LEFT_intj_UH', 'RIGHT_ccomp_VBP', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_advcl_VB', 'RIGHT_cc_IN', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_NN', 'RIGHT_cc_CC', 'RIGHT_conj_NNS', 'RIGHT_advcl_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_NNP', 'RIGHT_advmod_RB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_amod_JJ', 'LEFT_punct_,', 'RIGHT_dobj_NNS', 'RIGHT_dobj_NNS']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_advcl_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_NNP', 'RIGHT_advmod_RB', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBZ', 'LEFT_advcl_VBP', 'LEFT_punct_,', 'LEFT_nsubj_PRP', 'RIGHT_acomp_JJS', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NN', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_prep_IN', 'RIGHT_cc_CC', 'RIGHT_conj_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_nsubjpass_NNP', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VBP', 'LEFT_prep_IN', 'LEFT_punct_,', 'LEFT_csubj_VB', 'RIGHT_dobj_ADD', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_ccomp_VB', 'LEFT_punct_:', 'LEFT_nsubj_PRP', 'LEFT_aux_MD', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNP', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advmod_RB', 'LEFT_punct_,', 'RIGHT_dobj_NN', 'RIGHT_punct_,', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBG', 'LEFT_punct_,', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prt_RP', 'RIGHT_dobj_NNS', 'RIGHT_prep_IN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advmod_RB', 'LEFT_punct_,', 'RIGHT_dobj_NNS', 'RIGHT_oprd_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_ccomp_VBD', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubj_NNP', 'RIGHT_dobj_NNS', 'RIGHT_advmod_RB', 'RIGHT_prep_IN', 'RIGHT_punct_-RRB-', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBP', 'RIGHT_prep_IN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_PRP', 'LEFT_aux_MD', 'LEFT_advmod_RB', 'RIGHT_dobj_NNP', 'RIGHT_cc_CC', 'RIGHT_conj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_advmod_RB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_PRP', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_ccomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prep_IN', 'RIGHT_ccomp_VBD', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_ccomp_VBP', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prep_IN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_prep_IN', 'RIGHT_advcl_VBZ', 'RIGHT_punct_,', 'RIGHT_advcl_VBZ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dative_PRP', 'RIGHT_dobj_NN', 'RIGHT_punct_,', 'RIGHT_dobj_NN']
# action ['ROOT_self_VB', 'RIGHT_prep_IN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_advcl_VBP', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_NN', 'LEFT_compound_NN', 'LEFT_compound_NN', 'LEFT_punct_HYPH', 'RIGHT_cc_CC', 'RIGHT_conj_VBP']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_acl_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_aux_VB', 'LEFT_neg_RB', 'RIGHT_xcomp_VB']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_dobj_NN']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_dobj_PRP', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBG', 'LEFT_punct_,', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_ccomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_dative_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_RB', 'LEFT_punct_,', 'RIGHT_dobj_NNP', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_xcomp_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBG', 'LEFT_punct_,', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_NNS', 'LEFT_compound_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_NN', 'RIGHT_dobj_NNS', 'RIGHT_dobj_NNS', 'RIGHT_advmod_RB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_ccomp_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_aux_VB', 'LEFT_neg_RB', 'RIGHT_cc_CC', 'RIGHT_conj_NN', 'RIGHT_conj_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_ccomp_VBN']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_dobj_VBG', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_NNPS', 'LEFT_compound_NN', 'RIGHT_prep_IN', 'RIGHT_advcl_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_advmod_RB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBN', 'RIGHT_dobj_NN', 'RIGHT_advmod_RB', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBZ', 'LEFT_punct_,', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_cc_CC', 'RIGHT_conj_NN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_advmod_RB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubj_NNP', 'RIGHT_dobj_NNS', 'RIGHT_advmod_RB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advmod_RB', 'RIGHT_dobj_NNS', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VBP', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VBD', 'LEFT_nsubj_NNP', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_-RRB-', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_prep_IN']
# action ['ROOT_self_IN', 'RIGHT_pobj_NN', 'RIGHT_pcomp_VB']
# action ['ROOT_self_VB', 'RIGHT_prep_IN']
# action ['ROOT_self_VBP', 'LEFT_nsubj_NN', 'LEFT_advmod_RB', 'RIGHT_dobj_NN', 'RIGHT_dative_IN']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prep_IN']
# action ['ROOT_self_VBN', 'LEFT_advmod_RB', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_prep_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'LEFT_advmod_RB', 'RIGHT_dobj_NNS', 'RIGHT_prep_IN', 'RIGHT_ccomp_VB']
# action ['ROOT_self_VB', 'LEFT_aux_VB', 'LEFT_nsubj_NN', 'RIGHT_dobj_NN']
# action ['ROOT_self_VB', 'LEFT_advcl_VBZ', 'LEFT_punct_,', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_dobj_NNS']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_punct_,', 'RIGHT_cc_CC', 'RIGHT_conj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VBZ', 'LEFT_csubj_VBG', 'RIGHT_attr_NN']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_xcomp_VB']
# action ['ROOT_self_VB', 'LEFT_npadvmod_NN', 'LEFT_punct_HYPH', 'RIGHT_dobj_NN']
# action ['ROOT_self_VB', 'LEFT_advcl_VBZ', 'LEFT_punct_,', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'LEFT_advmod_RB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NN', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_prt_RP', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NN', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_prep_IN', 'RIGHT_cc_CC', 'RIGHT_conj_VBD', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBZ', 'LEFT_punct_,', 'RIGHT_dobj_NNS', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_advcl_VBZ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NN', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'LEFT_advmod_RB', 'RIGHT_advmod_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_cc_CC', 'RIGHT_conj_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_acomp_JJ', 'RIGHT_acomp_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_ccomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advmod_RB', 'RIGHT_dobj_NN', 'RIGHT_advcl_VBZ', 'RIGHT_punct_.']
# action ['ROOT_self_NN', 'RIGHT_dobj_NNS', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_NNS', 'LEFT_amod_VB', 'LEFT_nmod_NN', 'LEFT_amod_JJ', 'RIGHT_relcl_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prep_IN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_advmod_RB', 'LEFT_auxpass_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'LEFT_advmod_RB', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_xcomp_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_dobj_NN', 'RIGHT_parataxis_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_advcl_VBN', 'LEFT_punct_,', 'LEFT_nsubjpass_PRP', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubj_VB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_cc_CC', 'RIGHT_conj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VB', 'LEFT_punct_,', 'RIGHT_dobj_NN', 'RIGHT_conj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'LEFT_advmod_RB', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prt_RP', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_neg_RB', 'RIGHT_dobj_NN', 'RIGHT_prt_RP', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_xcomp_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_NNS', 'LEFT_compound_NN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_NNS', 'LEFT_compound_NN', 'RIGHT_advmod_RB', 'RIGHT_punct_.']
# action ['ROOT_self_NN', 'LEFT_advcl_VBZ', 'LEFT_punct_,', 'RIGHT_dobj_NN', 'RIGHT_prep_RB', 'RIGHT_advcl_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBZ', 'LEFT_punct_,', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_csubjpass_VB', 'LEFT_auxpass_VBZ', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advmod_RB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBP', 'LEFT_punct_,', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_attr_NN', 'RIGHT_conj_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBP', 'LEFT_punct_,', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_conj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_TO', 'RIGHT_dobj_NNS', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_ccomp_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_dobj_NN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'LEFT_advmod_RB', 'RIGHT_prep_IN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advmod_RB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_oprd_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_NNS', 'LEFT_nsubj_NN', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advmod_RB', 'RIGHT_dobj_NN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBP', 'LEFT_mark_IN', 'LEFT_nsubj_NNS', 'RIGHT_acomp_JJ', 'RIGHT_punct_VBZ', 'RIGHT_acomp_JJ', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_JJ', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VB', 'LEFT_punct_,', 'RIGHT_ccomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_ccomp_VBZ', 'RIGHT_punct_.']
# action ['ROOT_self_VBG', 'LEFT_mark_IN', 'LEFT_nsubj_PRP', 'LEFT_aux_VBP', 'RIGHT_dobj_NN', 'RIGHT_punct_,', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_acomp_JJ', 'RIGHT_cc_CC', 'RIGHT_conj_VBP', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NN', 'LEFT_auxpass_VBP', 'RIGHT_prep_IN', 'RIGHT_cc_CC', 'RIGHT_conj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_oprd_JJ', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_VBN', 'LEFT_aux_MD', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_PRP', 'LEFT_aux_MD', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_advcl_VB', 'RIGHT_cc_CC', 'RIGHT_conj_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_advmod_RB', 'RIGHT_cc_CC', 'RIGHT_advmod_RB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advmod_RB', 'RIGHT_ccomp_VBZ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_neg_RB', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_prep_IN', 'LEFT_nsubj_NN', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NN', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_advmod_RB', 'RIGHT_punct_,', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_ccomp_VBZ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_NNS', 'LEFT_compound_NN', 'LEFT_compound_NN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_NNS', 'LEFT_compound_NN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'RIGHT_dobj_NN', 'RIGHT_punct_-RRB-', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_NNS', 'LEFT_amod_JJ', 'RIGHT_punct_-LRB-', 'RIGHT_prep_IN', 'RIGHT_punct_-RRB-', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_advcl_VBP', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NN', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_cc_CC', 'RIGHT_conj_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubj_NN', 'LEFT_advmod_RB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBG', 'LEFT_nsubj_NNP', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_NN', 'RIGHT_amod_JJ', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VBD', 'LEFT_nsubj_NNP', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBD', 'LEFT_nsubj_NNS', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBD', 'LEFT_nsubj_NNS', 'RIGHT_prt_RP', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_NNS', 'LEFT_compound_NN', 'RIGHT_acl_VBN', 'RIGHT_punct_CD']
# action ['ROOT_self_VB', 'RIGHT_dobj_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VBP', 'RIGHT_dobj_NN']
# action ['ROOT_self_VB', 'RIGHT_dobj_PRP', 'RIGHT_dobj_NN', 'RIGHT_prep_IN']
# action ['ROOT_self_VBZ', 'LEFT_nsubj_PRP', 'RIGHT_acomp_JJ', 'RIGHT_ccomp_VBP', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'LEFT_advmod_RB', 'RIGHT_dobj_NNS', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_aux_VB', 'LEFT_nsubj_NN', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VBZ', 'LEFT_csubj_VBG', 'RIGHT_attr_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBZ', 'LEFT_nsubj_NNP', 'RIGHT_ccomp_VBP', 'RIGHT_punct_:']
# action ['ROOT_self_VBZ', 'LEFT_advcl_VBP', 'LEFT_nsubj_PRP', 'RIGHT_acomp_JJ', 'RIGHT_ccomp_VBP', 'RIGHT_punct_.']
# action ['ROOT_self_VBZ', 'LEFT_prep_IN', 'LEFT_punct_,', 'LEFT_nsubj_NN', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_cc_CC', 'LEFT_nsubjpass_NN', 'LEFT_aux_MD', 'LEFT_advmod_RB', 'LEFT_auxpass_VB', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_prep_IN', 'LEFT_punct_,', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'LEFT_advmod_RB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBN', 'LEFT_punct_,', 'LEFT_nsubj_PRP', 'LEFT_aux_MD', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_acomp_VBN', 'RIGHT_prep_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VBZ', 'LEFT_nsubj_PRP', 'RIGHT_advmod_RB', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNP', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_prep_IN', 'RIGHT_cc_CC', 'RIGHT_conj_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_attr_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'RIGHT_acomp_JJ', 'RIGHT_cc_CC', 'RIGHT_conj_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prep_IN', 'RIGHT_punct_,', 'RIGHT_advcl_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_prep_IN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VB', 'LEFT_punct_,', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_xcomp_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_prep_IN', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_dobj_NN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_xcomp_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advmod_RB', 'LEFT_punct_,', 'RIGHT_ccomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_csubj_VBG', 'LEFT_aux_MD', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_prep_IN', 'LEFT_punct_,', 'LEFT_nsubjpass_NN', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_prep_IN', 'LEFT_punct_,', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'RIGHT_advmod_RB', 'RIGHT_attr_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VBZ', 'LEFT_nsubj_PRP', 'RIGHT_acomp_JJ', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_advmod_RP', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_prep_IN', 'LEFT_punct_,', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VBP', 'LEFT_nsubj_NNS', 'RIGHT_attr_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBZ', 'LEFT_nsubj_PRP', 'RIGHT_acomp_JJ', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'LEFT_advmod_RB', 'RIGHT_attr_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_NNS', 'LEFT_compound_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VBD', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VBG', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VBG', 'RIGHT_dobj_NNS', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBG', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBG', 'LEFT_punct_,', 'LEFT_prep_IN', 'LEFT_punct_,', 'LEFT_aux_MD', 'RIGHT_dobj_NNS', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_auxpass_VBP', 'LEFT_advmod_RB', 'LEFT_neg_RB', 'RIGHT_punct_,', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_oprd_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBP', 'LEFT_punct_,', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBG', 'LEFT_punct_,', 'RIGHT_prt_RP', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_ccomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_advmod_RB', 'LEFT_auxpass_VB', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advcl_VBZ', 'LEFT_punct_,', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_ccomp_VBZ']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_prep_IN', 'RIGHT_cc_CC', 'RIGHT_conj_VBD', 'RIGHT_punct_.']
# action ['ROOT_self_NNS', 'LEFT_nsubj_NN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_advmod_RB', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_ccomp_VBP', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prt_RP', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# action ['ROOT_self_NNS', 'LEFT_compound_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VBD', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_prep_IN', 'LEFT_punct_,', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_dobj_NNS', 'RIGHT_cc_CC', 'RIGHT_conj_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_ccomp_VB']
# action ['ROOT_self_NNS', 'LEFT_compound_NN', 'RIGHT_prep_IN']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_CC', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_prep_IN', 'LEFT_punct_,', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_NNS', 'LEFT_compound_NNP', 'RIGHT_acl_VBG', 'RIGHT_cc_CC', 'RIGHT_conj_NN']
# action ['ROOT_self_VB', 'RIGHT_ccomp_JJ', 'RIGHT_punct_,', 'RIGHT_cc_CC', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prep_IN', 'RIGHT_acl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_attr_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_conj_VBD', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_conj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_dobj_VBG', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'LEFT_advmod_RB', 'RIGHT_prt_RP', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBZ', 'LEFT_csubj_VBG', 'RIGHT_attr_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_acomp_JJ', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_NN', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_prep_IN', 'LEFT_punct_,', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_advmod_RB', 'RIGHT_cc_CC', 'RIGHT_conj_VB']
# action ['ROOT_self_VB', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBZ', 'LEFT_advcl_VB', 'LEFT_punct_:', 'LEFT_nsubj_NN', 'RIGHT_acomp_JJ', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_parataxis_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_ccomp_VB', 'RIGHT_cc_CC', 'RIGHT_conj_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_ccomp_VBZ', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'RIGHT_prt_RP', 'RIGHT_dobj_NN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_NNS', 'LEFT_compound_NN', 'RIGHT_cc_CC', 'RIGHT_conj_NNS', 'RIGHT_prep_IN', 'RIGHT_acl_VBG', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_advcl_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'RIGHT_prt_RP', 'RIGHT_dobj_NN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_prep_IN']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_prep_IN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_cc_CC', 'RIGHT_conj_NNS', 'RIGHT_punct_,', 'RIGHT_relcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_cc_CC', 'RIGHT_conj_VBP']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'LEFT_advmod_RB', 'RIGHT_prt_RP', 'RIGHT_dobj_NN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_dobj_NN', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_prep_IN', 'LEFT_punct_,', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_prep_IN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NN', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_agent_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NNS', 'RIGHT_punct_,', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_dobj_NNS', 'RIGHT_prep_IN', 'RIGHT_cc_CC', 'RIGHT_conj_VB']
# action ['ROOT_self_VBP', 'LEFT_nsubj_NNS', 'RIGHT_attr_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_advmod_RB', 'LEFT_auxpass_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_prt_RP', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'LEFT_advmod_RB', 'RIGHT_dobj_NN', 'RIGHT_punct_,', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'LEFT_advmod_RB', 'RIGHT_prep_IN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'RIGHT_ccomp_VBP', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_xcomp_VB', 'RIGHT_cc_CC', 'RIGHT_conj_VBN', 'RIGHT_punct_.']
# action ['ROOT_self_VB', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# ...
# non_action ['ROOT_self_VBZ', 'LEFT_advmod_RB', 'LEFT_punct_,', 'LEFT_nsubj_PRP', 'RIGHT_advmod_RB', 'RIGHT_acomp_JJ', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'RIGHT_dobj_NN', 'RIGHT_punct_-RRB-', 'RIGHT_cc_CC', 'RIGHT_conj_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'RIGHT_dobj_NN', 'RIGHT_punct_-RRB-', 'RIGHT_cc_CC', 'RIGHT_conj_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBP', 'LEFT_nsubj_NNS', 'RIGHT_prep_IN', 'RIGHT_advcl_VBP', 'RIGHT_punct_:']
# non_action ['ROOT_self_VBP', 'LEFT_nsubj_NNS', 'RIGHT_prep_IN', 'RIGHT_advcl_VBP', 'RIGHT_punct_:']
# non_action ['ROOT_self_VBD', 'LEFT_prep_IN', 'LEFT_nsubj_NNP', 'LEFT_nsubj_NNP', 'RIGHT_dobj_NNP', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBD', 'LEFT_prep_IN', 'LEFT_nsubj_NNP', 'LEFT_nsubj_NNP', 'RIGHT_dobj_NNP', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_prep_IN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_prep_IN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'RIGHT_dobj_NN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'RIGHT_dobj_NN', 'RIGHT_advcl_VB', 'RIGHT_punct_.']
# non_action ['ROOT_self_NN', 'LEFT_nummod_CD', 'LEFT_amod_JJ', 'RIGHT_relcl_VB']
# non_action ['ROOT_self_NN', 'LEFT_nummod_CD', 'LEFT_amod_JJ', 'RIGHT_relcl_VB']
# non_action ['ROOT_self_VBD', 'LEFT_nsubj_NNS', 'LEFT_punct_,', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBD', 'LEFT_nsubj_NNS', 'LEFT_punct_,', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_auxpass_VBD', 'RIGHT_xcomp_VB', 'RIGHT_punct_,', 'RIGHT_cc_CC', 'RIGHT_conj_VBN']
# non_action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_auxpass_VBD', 'RIGHT_xcomp_VB', 'RIGHT_punct_,', 'RIGHT_cc_CC', 'RIGHT_conj_VBN']
# non_action ['ROOT_self_VBG', 'LEFT_nsubj_NNS', 'RIGHT_dobj_NNS', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBG', 'LEFT_nsubj_NNS', 'RIGHT_dobj_NNS', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_advcl_VBZ', 'LEFT_punct_,', 'LEFT_expl_EX', 'LEFT_aux_MD', 'RIGHT_attr_NNS', 'RIGHT_punct_,', 'RIGHT_advcl_VBP', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_advcl_VBZ', 'LEFT_punct_,', 'LEFT_expl_EX', 'LEFT_aux_MD', 'RIGHT_attr_NNS', 'RIGHT_punct_,', 'RIGHT_advcl_VBP', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBP', 'LEFT_nsubj_NNS', 'RIGHT_prep_IN', 'RIGHT_prep_IN', 'RIGHT_punct_:', 'RIGHT_conj_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBP', 'LEFT_nsubj_NNS', 'RIGHT_prep_IN', 'RIGHT_prep_IN', 'RIGHT_punct_:', 'RIGHT_conj_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_ccomp_VBZ', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_ccomp_VBZ', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBN', 'LEFT_advcl_VBN', 'LEFT_advmod_RB', 'LEFT_punct_,', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBN', 'LEFT_advcl_VBN', 'LEFT_advmod_RB', 'LEFT_punct_,', 'LEFT_nsubjpass_NNS', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_punct_.']
# non_action ['ROOT_self_NNS', 'LEFT_advcl_VBP', 'LEFT_nsubj_NN', 'RIGHT_dobj_VBZ', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_NNS', 'LEFT_advcl_VBP', 'LEFT_nsubj_NN', 'RIGHT_dobj_VBZ', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_advcl_VBZ', 'LEFT_advcl_VBZ', 'LEFT_punct_,', 'LEFT_nsubj_NN', 'RIGHT_prep_IN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_advcl_VBZ', 'LEFT_advcl_VBZ', 'LEFT_punct_,', 'LEFT_nsubj_NN', 'RIGHT_prep_IN', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'LEFT_advmod_RB', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_punct_,', 'RIGHT_advcl_VBG', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'LEFT_advmod_RB', 'RIGHT_dobj_NN', 'RIGHT_prep_IN', 'RIGHT_punct_,', 'RIGHT_advcl_VBG', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_csubj_VBP', 'LEFT_advmod_RB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_csubj_VBP', 'LEFT_advmod_RB', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBN', 'LEFT_nsubjpass_NN', 'LEFT_punct_,', 'LEFT_prep_IN', 'LEFT_punct_,', 'LEFT_auxpass_VBZ', 'LEFT_advmod_RB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBN', 'LEFT_nsubjpass_NN', 'LEFT_punct_,', 'LEFT_prep_IN', 'LEFT_punct_,', 'LEFT_auxpass_VBZ', 'LEFT_advmod_RB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_NNP', 'LEFT_prep_IN', 'LEFT_punct_,', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_prep_IN']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_NNP', 'LEFT_prep_IN', 'LEFT_punct_,', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_prep_IN']
# non_action ['ROOT_self_CD', 'LEFT___SP', 'RIGHT___SP', 'RIGHT_conj_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_CD', 'LEFT___SP', 'RIGHT___SP', 'RIGHT_conj_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBP', 'LEFT_nsubj_NNS', 'RIGHT_dobj_NN', 'RIGHT_punct_,', 'RIGHT_cc_CC', 'RIGHT_conj_VB']
# non_action ['ROOT_self_VBP', 'LEFT_nsubj_NNS', 'RIGHT_dobj_NN', 'RIGHT_punct_,', 'RIGHT_cc_CC', 'RIGHT_conj_VB']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_PRP', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_PRP', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBD', 'LEFT_nsubj_NN', 'RIGHT_prep_IN', 'RIGHT_punct_,', 'RIGHT_npadvmod_NNP', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBD', 'LEFT_nsubj_NN', 'RIGHT_prep_IN', 'RIGHT_punct_,', 'RIGHT_npadvmod_NNP', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBN', 'LEFT_nsubjpass_NN', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBN', 'LEFT_nsubjpass_NN', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_advcl_VBZ', 'LEFT_punct_,', 'LEFT_nsubj_NN', 'RIGHT_acomp_JJR', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_advcl_VBZ', 'LEFT_punct_,', 'LEFT_nsubj_NN', 'RIGHT_acomp_JJR', 'RIGHT_punct_.']
# non_action ['ROOT_self_NNS', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_NNS', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_NN', 'LEFT_prep_IN', 'LEFT_punct_,', 'LEFT_nsubj_NNP', 'LEFT_aux_VBD', 'LEFT_advmod_RB', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VBG', 'RIGHT_punct_.']
# non_action ['ROOT_self_NN', 'LEFT_prep_IN', 'LEFT_punct_,', 'LEFT_nsubj_NNP', 'LEFT_aux_VBD', 'LEFT_advmod_RB', 'RIGHT_dobj_NN', 'RIGHT_cc_CC', 'RIGHT_conj_VBG', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNPS', 'LEFT_aux_VBP', 'LEFT_auxpass_VBN', 'RIGHT_prep_IN', 'RIGHT_advcl_VB', 'RIGHT_punct_,', 'RIGHT_cc_CC', 'RIGHT_conj_VBP']
# non_action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNPS', 'LEFT_aux_VBP', 'LEFT_auxpass_VBN', 'RIGHT_prep_IN', 'RIGHT_advcl_VB', 'RIGHT_punct_,', 'RIGHT_cc_CC', 'RIGHT_conj_VBP']
# non_action ['ROOT_self_VBP', 'LEFT_nsubj_NNS', 'LEFT_advmod_RB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBP', 'LEFT_nsubj_NNS', 'LEFT_advmod_RB', 'RIGHT_dobj_NNS', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBP', 'LEFT_nsubj_PRP', 'RIGHT_dobj_NN', 'RIGHT_punct_,', 'RIGHT_advcl_VBP', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBP', 'LEFT_nsubj_PRP', 'RIGHT_dobj_NN', 'RIGHT_punct_,', 'RIGHT_advcl_VBP', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBG', 'LEFT_nsubj_NNS', 'LEFT_aux_VBP', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBG', 'LEFT_nsubj_NNS', 'LEFT_aux_VBP', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_ccomp_VB', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_ccomp_VB', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_advmod_RB', 'LEFT_punct_,', 'LEFT_nsubj_NN', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_advmod_RB', 'LEFT_punct_,', 'LEFT_nsubj_NN', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'LEFT_advmod_RB', 'RIGHT_dobj_NNS', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'LEFT_advmod_RB', 'RIGHT_dobj_NNS', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_NNP', 'RIGHT_attr_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_NNP', 'RIGHT_attr_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_mark_IN', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_mark_IN', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_advmod_RB', 'LEFT_punct_,', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_attr_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_advmod_RB', 'LEFT_punct_,', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_attr_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_PRP', 'RIGHT_acomp_JJ', 'RIGHT_xcomp_VB', 'RIGHT_advcl_VBZ', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_PRP', 'RIGHT_acomp_JJ', 'RIGHT_xcomp_VB', 'RIGHT_advcl_VBZ', 'RIGHT_punct_.']
# non_action ['ROOT_self_NNS', 'RIGHT_prep_IN']
# non_action ['ROOT_self_NNS', 'RIGHT_prep_IN']
# non_action ['ROOT_self_VBP', 'LEFT_nsubj_NNS', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBP', 'LEFT_nsubj_NNS', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_prep_IN', 'RIGHT_advmod_RB', 'RIGHT_punct_,', 'RIGHT_cc_CC', 'RIGHT_conj_VB']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_prep_IN', 'RIGHT_advmod_RB', 'RIGHT_punct_,', 'RIGHT_cc_CC', 'RIGHT_conj_VB']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_xcomp_VB', 'RIGHT_cc_CC', 'RIGHT_conj_VB']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_xcomp_VB', 'RIGHT_cc_CC', 'RIGHT_conj_VB']
# non_action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_auxpass_VBP', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_auxpass_VBP', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBG', 'RIGHT_cc_CC', 'RIGHT_conj_VBG', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBG', 'RIGHT_cc_CC', 'RIGHT_conj_VBG', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBP', 'LEFT_nsubj_DT', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBP', 'LEFT_nsubj_DT', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBN', 'LEFT_nsubjpass_NN', 'LEFT_auxpass_VBZ', 'RIGHT_oprd_JJ', 'RIGHT_advcl_VBN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBN', 'LEFT_nsubjpass_NN', 'LEFT_auxpass_VBZ', 'RIGHT_oprd_JJ', 'RIGHT_advcl_VBN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'LEFT_punct_,', 'LEFT_prep_IN', 'LEFT_punct_,', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'LEFT_punct_,', 'LEFT_prep_IN', 'LEFT_punct_,', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_dobj_NN', 'RIGHT_advcl_VBP', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_aux_MD', 'RIGHT_dobj_NN', 'RIGHT_advcl_VBP', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBN', 'LEFT_nsubjpass_NN', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBN', 'LEFT_nsubjpass_NN', 'LEFT_aux_MD', 'LEFT_auxpass_VB', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_PRP', 'RIGHT_dobj_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_PRP', 'RIGHT_dobj_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBP', 'LEFT_nsubj_NNS', 'RIGHT_acomp_JJ', 'RIGHT_advcl_VB']
# non_action ['ROOT_self_VBP', 'LEFT_nsubj_NNS', 'RIGHT_acomp_JJ', 'RIGHT_advcl_VB']
# non_action ['ROOT_self_NNS', 'LEFT_amod_CD', 'LEFT_amod_JJ', 'LEFT_compound_NN', 'RIGHT_relcl_VBP', 'RIGHT_punct_:']
# non_action ['ROOT_self_NNS', 'LEFT_amod_CD', 'LEFT_amod_JJ', 'LEFT_compound_NN', 'RIGHT_relcl_VBP', 'RIGHT_punct_:']
# non_action ['ROOT_self_VBP', 'LEFT_nsubj_NNS', 'RIGHT_punct_:']
# non_action ['ROOT_self_VBP', 'LEFT_nsubj_NNS', 'RIGHT_punct_:']
# non_action ['ROOT_self_NNS', 'LEFT_amod_CD', 'LEFT_amod_JJR', 'RIGHT_prep_IN', 'RIGHT_prep_IN', 'RIGHT_punct_:']
# non_action ['ROOT_self_NNS', 'LEFT_amod_CD', 'LEFT_amod_JJR', 'RIGHT_prep_IN', 'RIGHT_prep_IN', 'RIGHT_punct_:']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'LEFT_punct_POS', 'LEFT_nsubj_NN', 'RIGHT_attr_NNP', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_NN', 'LEFT_punct_POS', 'LEFT_nsubj_NN', 'RIGHT_attr_NNP', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_ccomp_VB', 'LEFT_punct_:', 'LEFT_advmod_RB', 'LEFT_punct_,', 'LEFT_nsubj_NN', 'RIGHT_neg_RB', 'RIGHT_advmod_RB', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_ccomp_VB', 'LEFT_punct_:', 'LEFT_advmod_RB', 'LEFT_punct_,', 'LEFT_nsubj_NN', 'RIGHT_neg_RB', 'RIGHT_advmod_RB', 'RIGHT_acomp_JJ', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBN', 'LEFT_advmod_WRB', 'LEFT_aux_MD', 'LEFT_nsubjpass_PRP', 'LEFT_auxpass_VB', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBN', 'LEFT_advmod_WRB', 'LEFT_aux_MD', 'LEFT_nsubjpass_PRP', 'LEFT_auxpass_VB', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_DT', 'LEFT_aux_MD', 'RIGHT_prt_RP', 'RIGHT_dobj_NNS', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_DT', 'LEFT_aux_MD', 'RIGHT_prt_RP', 'RIGHT_dobj_NNS', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_prep_IN', 'LEFT_punct_,', 'LEFT_nsubj_NN', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_acomp_JJ', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_prep_IN', 'LEFT_punct_,', 'LEFT_nsubj_NN', 'LEFT_nsubj_NN', 'LEFT_aux_MD', 'RIGHT_acomp_JJ', 'RIGHT_xcomp_VB', 'RIGHT_punct_.']
# non_action ['ROOT_self_IN', 'RIGHT_pobj_NNP', 'RIGHT_pobj_NNP']
# non_action ['ROOT_self_IN', 'RIGHT_pobj_NNP', 'RIGHT_pobj_NNP']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_NNP', 'RIGHT_attr_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBZ', 'LEFT_nsubj_NNP', 'RIGHT_attr_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_advmod_RB', 'LEFT_aux_MD', 'LEFT_neg_RB', 'RIGHT_dobj_NNS', 'RIGHT_prep_IN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'LEFT_nsubj_NNS', 'LEFT_advmod_RB', 'LEFT_aux_MD', 'LEFT_neg_RB', 'RIGHT_dobj_NNS', 'RIGHT_prep_IN', 'RIGHT_cc_CC', 'RIGHT_conj_VB', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBP', 'LEFT_prep_IN', 'LEFT_punct_,', 'LEFT_nsubj_NNS', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBP', 'LEFT_prep_IN', 'LEFT_punct_,', 'LEFT_nsubj_NNS', 'RIGHT_dobj_NN', 'RIGHT_punct_.']
# non_action ['ROOT_self_NNS', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_NNS', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_NNP', 'LEFT_compound_NNP', 'RIGHT_punct_,', 'RIGHT_appos_NNP', 'RIGHT_punct_.']
# non_action ['ROOT_self_NNP', 'LEFT_compound_NNP', 'RIGHT_punct_,', 'RIGHT_appos_NNP', 'RIGHT_punct_.']
# non_action ['ROOT_self_NFP', 'RIGHT___SP']
# non_action ['ROOT_self_NFP', 'RIGHT___SP']
# non_action ['ROOT_self_NNP', 'LEFT_det_DT', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_NNP', 'LEFT_det_DT', 'RIGHT_prep_IN', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'RIGHT_ccomp_VBZ', 'RIGHT_punct_.']
# non_action ['ROOT_self_VB', 'RIGHT_ccomp_VBZ', 'RIGHT_punct_.']
# non_action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_auxpass_VBD', 'LEFT_neg_RB', 'RIGHT_xcomp_VB', 'RIGHT_punct_,', 'RIGHT_cc_CC', 'RIGHT_conj_VBD']
# non_action ['ROOT_self_VBN', 'LEFT_nsubjpass_NNS', 'LEFT_auxpass_VBD', 'LEFT_neg_RB', 'RIGHT_xcomp_VB', 'RIGHT_punct_,', 'RIGHT_cc_CC', 'RIGHT_conj_VBD']

# %% [markdown]
# ###Logistic Regression

# %%
# where to save the models
# %cd '/gdrive/My Drive/Colab Notebooks/3666 ANLP/Project'

# tiny corpus for testing
#docs=corpus[0:20]+corpus[-20:-1]
#labs=labels[0:20]+labels[-20:-1]

# whole corpus
docs=corpus
labs=labels

# Vectorizer
v=GensimTfidfVectorizer(".", True) 
vecs=v.fit_transform(docs)

# K-fold splitter for cross-validation
loader = CorpusLoader(vecs, labs, 10) 

# Storage for all our model metrics
#fields = ['precision', 'recall', 'accuracy', 'f1']
#scores = defaultdict(list)
#for f in fields:
#    scores[f]=[]

for X_train, X_test, y_train, y_test in loader:
    m=LogisticRegression()
    m.fit(X_train, y_train)
    y_pred=m.predict(X_test)
    #score = accuracy_score(y_test, y_pred)
    #scores.append(score)

    print(classification_report(y_test, y_pred))

    # Add scores to our scores
    #scores['precision'].append(precision_score(y_test, y_pred))
    #scores['recall'].append(recall_score(y_test, y_pred))
    #scores['accuracy'].append(accuracy_score(y_test, y_pred))
    #scores['f1'].append(f1_score(y_test, y_pred))

#print("Results for model {}".format(m))
#print("  Precision: {:0.3f}".format(np.mean(scores['precision'])))
#print("  Recall:    {:0.3f}".format(np.mean(scores['recall'])))
#print("  Accuracy:  {:0.3f}".format(np.mean(scores['accuracy'])))
#print("  F1:        {:0.3f}".format(np.mean(scores['f1'])))
# Out:
# /gdrive/My Drive/Colab Notebooks/3666 ANLP/Project
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
#               precision    recall  f1-score   support
#
#       action       0.78      0.83      0.80        76
#   non_action       0.84      0.79      0.81        84
#
#     accuracy                           0.81       160
#    macro avg       0.81      0.81      0.81       160
# weighted avg       0.81      0.81      0.81       160
#
#               precision    recall  f1-score   support
#
#       action       0.81      0.83      0.82        83
#   non_action       0.81      0.79      0.80        77
#
#     accuracy                           0.81       160
#    macro avg       0.81      0.81      0.81       160
# weighted avg       0.81      0.81      0.81       160
#
#               precision    recall  f1-score   support
#
#       action       0.73      0.80      0.76        70
#   non_action       0.83      0.77      0.80        90
#
#     accuracy                           0.78       160
#    macro avg       0.78      0.78      0.78       160
# weighted avg       0.79      0.78      0.78       160
#
#               precision    recall  f1-score   support
#
#       action       0.81      0.83      0.82        87
#   non_action       0.79      0.77      0.78        73
#
#     accuracy                           0.80       160
#    macro avg       0.80      0.80      0.80       160
# weighted avg       0.80      0.80      0.80       160
#
#               precision    recall  f1-score   support
#
#       action       0.90      0.80      0.85        92
#   non_action       0.77      0.88      0.82        68
#
#     accuracy                           0.84       160
#    macro avg       0.84      0.84      0.84       160
# weighted avg       0.85      0.84      0.84       160
#
#               precision    recall  f1-score   support
#
#       action       0.92      0.76      0.83        85
#   non_action       0.78      0.92      0.84        75
#
#     accuracy                           0.84       160
#    macro avg       0.85      0.84      0.84       160
# weighted avg       0.85      0.84      0.84       160
#
#               precision    recall  f1-score   support
#
#       action       0.91      0.87      0.89        79
#   non_action       0.88      0.91      0.90        80
#
#     accuracy                           0.89       159
#    macro avg       0.89      0.89      0.89       159
# weighted avg       0.89      0.89      0.89       159
#
#               precision    recall  f1-score   support
#
#       action       0.86      0.79      0.82        85
#   non_action       0.78      0.85      0.81        74
#
#     accuracy                           0.82       159
#    macro avg       0.82      0.82      0.82       159
# weighted avg       0.82      0.82      0.82       159
#
#               precision    recall  f1-score   support
#
#       action       0.83      0.81      0.82        84
#   non_action       0.79      0.81      0.80        75
#
#     accuracy                           0.81       159
#    macro avg       0.81      0.81      0.81       159
# weighted avg       0.81      0.81      0.81       159
#
#               precision    recall  f1-score   support
#
#       action       0.85      0.84      0.84        79
#   non_action       0.84      0.85      0.84        80
#
#     accuracy                           0.84       159
#    macro avg       0.84      0.84      0.84       159
# weighted avg       0.84      0.84      0.84       159
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# ### Read in the Pickled Parses and Labels
#
# Non-actions are duplicated to approximate the same number as the Actions, so the training data is balanced.

# %%
# location of pickle files
actions_file = '/gdrive/My Drive/Colab Notebooks/3666 ANLP/Project/Climate Change Docs - Actions.pkl'
non_actions_file = '/gdrive/My Drive/Colab Notebooks/3666 ANLP/Project/Climate Change Docs - Non-Actions.pkl'

#initialize accumulators
corpus = []
labels = []

with open(actions_file, 'r', encoding="utf8", errors='ignore') as f:
    reader = csv.reader(f, delimiter=' ')
    for row in reader:
        corpus.append(row)
        labels.append('action')

with open(non_actions_file, 'r', encoding="utf8", errors='ignore') as f:
    reader = csv.reader(f, delimiter=' ')
    for row in reader:
        corpus.append(row)
        corpus.append(row)
        labels.append('non_action')
        labels.append('non_action')

# %%
len(corpus)
# Out:
# 1596

# %% [markdown]
# ###Logistic Regression with Truncated SVD

# %%
# where to save the models
# %cd '/gdrive/My Drive/Colab Notebooks/3666 ANLP/Project'

# tiny corpus for testing
#docs=corpus[0:20]+corpus[-20:-1]
#labs=labels[0:20]+labels[-20:-1]

# whole corpus
docs=corpus
labs=labels

# Vectorizer
v=GensimTfidfVectorizer(".", True) 
vecs=v.fit_transform(docs)

# Truncated SVD
t=TruncatedSVD(n_components=5)
vecs_reduced=t.fit_transform(vecs)

# K-fold splitter for cross-validation
loader = CorpusLoader(vecs_reduced, labs, 10) 

for X_train, X_test, y_train, y_test in loader:
    m=LogisticRegression()
    m.fit(X_train, y_train)
    y_pred=m.predict(X_test)

    print(classification_report(y_test, y_pred))
# Out:
# /gdrive/My Drive/Colab Notebooks/3666 ANLP/Project
#               precision    recall  f1-score   support
#
#       action       0.66      0.64      0.65        80
#   non_action       0.65      0.68      0.66        80
#
#     accuracy                           0.66       160
#    macro avg       0.66      0.66      0.66       160
# weighted avg       0.66      0.66      0.66       160
#
#               precision    recall  f1-score   support
#
#       action       0.75      0.65      0.70        89
#   non_action       0.63      0.73      0.68        71
#
#     accuracy                           0.69       160
#    macro avg       0.69      0.69      0.69       160
# weighted avg       0.70      0.69      0.69       160
#
#               precision    recall  f1-score   support
#
#       action       0.72      0.56      0.63        93
#   non_action       0.53      0.70      0.61        67
#
#     accuracy                           0.62       160
#    macro avg       0.63      0.63      0.62       160
# weighted avg       0.64      0.62      0.62       160
#
#               precision    recall  f1-score   support
#
#       action       0.78      0.73      0.75        81
#   non_action       0.74      0.78      0.76        79
#
#     accuracy                           0.76       160
#    macro avg       0.76      0.76      0.76       160
# weighted avg       0.76      0.76      0.76       160
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:402: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#               precision    recall  f1-score   support
#
#       action       0.70      0.71      0.71        77
#   non_action       0.73      0.71      0.72        83
#
#     accuracy                           0.71       160
#    macro avg       0.71      0.71      0.71       160
# weighted avg       0.71      0.71      0.71       160
#
#               precision    recall  f1-score   support
#
#       action       0.65      0.70      0.67        73
#   non_action       0.73      0.68      0.70        87
#
#     accuracy                           0.69       160
#    macro avg       0.69      0.69      0.69       160
# weighted avg       0.69      0.69      0.69       160
#
#               precision    recall  f1-score   support
#
#       action       0.78      0.71      0.74        75
#   non_action       0.76      0.82      0.79        84
#
#     accuracy                           0.77       159
#    macro avg       0.77      0.76      0.76       159
# weighted avg       0.77      0.77      0.77       159
#
#               precision    recall  f1-score   support
#
#       action       0.66      0.69      0.68        74
#   non_action       0.72      0.69      0.71        85
#
#     accuracy                           0.69       159
#    macro avg       0.69      0.69      0.69       159
# weighted avg       0.69      0.69      0.69       159
#
#               precision    recall  f1-score   support
#
#       action       0.81      0.79      0.80        87
#   non_action       0.76      0.78      0.77        72
#
#     accuracy                           0.79       159
#    macro avg       0.78      0.79      0.78       159
# weighted avg       0.79      0.79      0.79       159
#
#               precision    recall  f1-score   support
#
#       action       0.74      0.70      0.72        91
#   non_action       0.63      0.68      0.65        68
#
#     accuracy                           0.69       159
#    macro avg       0.69      0.69      0.69       159
# weighted avg       0.70      0.69      0.69       159
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# # Extra stuff below this line is not used or tested

# %%
## Now we can quickly Generate models as follows:

# Here "models" is storing Pipeline objects 
models = []
#for form in (LogisticRegression, MultinomialNB, SGDClassifier): ##MultinomialNB removed because it was generating an error
for form in (LogisticRegression, SGDClassifier):
    #models.append(create_pipeline(form(), True))
    models.append(create_pipeline(form(), False))
